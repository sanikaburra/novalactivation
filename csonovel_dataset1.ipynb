# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

ignaciovinuales_battery_remaining_useful_life_rul_path = kagglehub.dataset_download('ignaciovinuales/battery-remaining-useful-life-rul')
geethapitta17_battery_rul_path = kagglehub.dataset_download('geethapitta17/battery-rul')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/ignaciovinuales/battery-remaining-useful-life-rul?dataset_version_number=3...
# 100%|██████████| 374k/374k [00:00<00:00, 34.0MB/s]
# Extracting files...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/geethapitta17/battery-rul?dataset_version_number=1...
# 100%|██████████| 374k/374k [00:00<00:00, 46.9MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# # Imports

# %%
import pandas as pd

import numpy as np

import os, glob

import matplotlib.pyplot as plt

import seaborn



from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

from sklearn.svm import SVC

from sklearn.datasets import load_iris



import tensorflow as tf
devs = tf.config.list_physical_devices('GPU')
for dev in devs:
    tf.config.experimental.set_memory_growth(dev, True)
    print(dev)

from tensorflow.keras import Sequential, optimizers, losses, layers



# %matplotlib inline

# %% [markdown]
# # Data Pre-processing

# %%
df_overview = pd.read_csv('/Battery_RUL.csv')
df_overview.head()
# Out:
#    Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# 0          1.0             2595.30             1151.488500
# 1          2.0             7408.64             1172.512500
# 2          3.0             7393.76             1112.992000
# 3          4.0             7385.50             1080.320667
# 4          6.0            65022.75            29813.487000
#
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# 0                      3.670                    3.211           5460.001
# 1                      4.246                    3.220           5508.992
# 2                      4.249                    3.224           5508.993
# 3                      4.250                    3.225           5502.016
# 4                      4.290                    3.398           5480.992
#
#    Time constant current (s)  Charging time (s)   RUL
# 0                    6755.01           10777.82  1112
# 1                    6762.02           10500.35  1111
# 2                    6762.02           10420.38  1110
# 3                    6762.02           10322.81  1109
# 4                   53213.54           56699.65  1107

# %%
def plot_dataframe_subplots(df, nrows, ncols, figsize=(30, 24)):
    """Plot a nrows x ncols grid of the df variables against the first column."""

    measurements = list(df.columns)
    plt.figure(figsize=figsize)

    # Use measurements[0] as the x-axis for all other variables
    x_values = df[measurements[0]]  # X-axis variable

    for idx, key in enumerate(measurements[1:], 1):  # Start from second measurement
        plt.subplot(nrows, ncols, idx)
        plt.plot(x_values, df[key])  # Plot other variables against measurements[0]
        plt.ylabel(key)
        plt.grid(True)
        plt.xlabel(measurements[0])  # X-axis is always measurements[0]

    plt.tight_layout()
    plt.show()

# %%
df_master = df_overview

print(list(df_master.columns.values))
# Out:
# ['Cycle_Index', 'Discharge Time (s)', 'Decrement 3.6-3.4V (s)', 'Max. Voltage Dischar. (V)', 'Min. Voltage Charg. (V)', 'Time at 4.15V (s)', 'Time constant current (s)', 'Charging time (s)', 'RUL']

# %%
df_master.head()
# Out:
#    Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# 0          1.0             2595.30             1151.488500
# 1          2.0             7408.64             1172.512500
# 2          3.0             7393.76             1112.992000
# 3          4.0             7385.50             1080.320667
# 4          6.0            65022.75            29813.487000
#
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# 0                      3.670                    3.211           5460.001
# 1                      4.246                    3.220           5508.992
# 2                      4.249                    3.224           5508.993
# 3                      4.250                    3.225           5502.016
# 4                      4.290                    3.398           5480.992
#
#    Time constant current (s)  Charging time (s)   RUL
# 0                    6755.01           10777.82  1112
# 1                    6762.02           10500.35  1111
# 2                    6762.02           10420.38  1110
# 3                    6762.02           10322.81  1109
# 4                   53213.54           56699.65  1107

# %%
import pandas as pd

# get columns with NaN values

cols_with_nan = df_master.columns[df_master.isna().any()].tolist()



# print out columns with NaN values and how many NaN values they have

for col in cols_with_nan:

    print(col, "has", df_master[col].isna().sum(), "NaN values")

# %%
dftest = df_master

# %%
print(list(dftest.columns.values))
# Out:
# ['Cycle_Index', 'Discharge Time (s)', 'Decrement 3.6-3.4V (s)', 'Max. Voltage Dischar. (V)', 'Min. Voltage Charg. (V)', 'Time at 4.15V (s)', 'Time constant current (s)', 'Charging time (s)', 'RUL']

# %%
import pandas as pd

# get columns with NaN values

cols_with_nan = dftest.columns[dftest.isna().any()].tolist()



# print out columns with NaN values and how many NaN values they have

for col in cols_with_nan:

    print(col, "has", dftest[col].isna().sum(), "NaN values")

# %%
dftest=dftest.dropna()

# %%
import pandas as pd

# get columns with NaN values

cols_with_nan = dftest.columns[dftest.isna().any()].tolist()



# print out columns with NaN values and how many NaN values they have

for col in cols_with_nan:

    print(col, "has", dftest[col].isna().sum(), "NaN values")

# %%
print(list(dftest.columns.values))
# Out:
# ['Cycle_Index', 'Discharge Time (s)', 'Decrement 3.6-3.4V (s)', 'Max. Voltage Dischar. (V)', 'Min. Voltage Charg. (V)', 'Time at 4.15V (s)', 'Time constant current (s)', 'Charging time (s)', 'RUL']

# %%
def set_negative_plot_color():

    plt.figure(figsize=(30, 6), facecolor='black')

    ax = plt.axes()

    ax.set_facecolor("black")

    ax.spines['bottom'].set_color('white')

    ax.spines['top'].set_color('white')

    ax.spines['right'].set_color('white')

    ax.spines['left'].set_color('white')

    ax.tick_params(colors='white', which='both')

    plt.grid(True)



def regression_metrics(y_test, y_pred):

    # calculate errors

    mse = mean_squared_error(y_test, y_pred)

    rmse = mean_squared_error(y_test, y_pred, squared=False)

    eps = 1e-10 # a small value to avoid division by zero

    rmspe = np.sqrt(np.mean(np.square((y_test - y_pred) / (y_test + eps))))

    #rmspe = np.sqrt(np.mean(np.square(((y_test - y_pred)/y_test)), axis=0))

    mae = mean_absolute_error(y_test, y_pred)

    mape = mean_absolute_percentage_error(y_test, y_pred)

    # report error

    print(f'Mean Squared Error: {mse}')

    print(f'Root Mean Square Error: {rmse}')

    print(f'Root Mean Square Percentage Error: {rmspe}')

    print(f'Mean Absolute Error: {mae}')

    print(f'Mean Absolute Percentage Error: {mape}')





def plot_comparison(y_test, y_pred, xlabel, ylabel, dark_mode=False, figsize=(30, 6)):

    import matplotlib as mpl

    mpl.rcParams['agg.path.chunksize'] = 200

    mpl.rcParams['path.simplify_threshold'] = 0.5

    if dark_mode:

        plt.figure(figsize=figsize, facecolor='black')

        ax = plt.axes()

        ax.set_facecolor("black")

        ax.spines['bottom'].set_color('gray')

        ax.spines['top'].set_color('gray')

        ax.spines['right'].set_color('gray')

        ax.spines['left'].set_color('gray')

        ax.tick_params(colors='white', which='both')

        plt.plot(y_pred, color="yellow")

        plt.plot(y_test, color="white")

        plt.legend(['Predicted', 'Measured'])

        plt.xlabel(xlabel, color='white')

        plt.ylabel(ylabel, color='white')

    else:

        plt.figure(figsize=figsize)

        plt.plot(y_pred)

        plt.plot(y_test)

        plt.legend(['Predicted', 'Measured'])

        plt.xlabel(xlabel)

        plt.ylabel(ylabel)

    plt.grid(True)

# %%
X=dftest.drop(['RUL'],axis=1)

y= dftest['RUL']

# %%
df_x_y = dftest

# %%
print(list(df_x_y.columns.values))
# Out:
# ['Cycle_Index', 'Discharge Time (s)', 'Decrement 3.6-3.4V (s)', 'Max. Voltage Dischar. (V)', 'Min. Voltage Charg. (V)', 'Time at 4.15V (s)', 'Time constant current (s)', 'Charging time (s)', 'RUL']

# %%
# from sklearn.model_selection import train_test_split

X = df_x_y.drop(['RUL'], axis=1)

y = df_x_y[['RUL']]  # Close the square bracket

# Split the data into train and test sets with a ratio of 95:5

splitter = int(len(X) * 0.95)

X_train, X_test = X.values[:splitter], X.values[splitter:]

y_train, y_test = y.values[:splitter], y.values[splitter:]



# Split the train set into train and validation sets with a ratio of 90:10

splitter1 = int(len(X_train) * 0.9)

X_train, X_val = X_train[:splitter1], X_train[splitter1:]

y_train, y_val = y_train[:splitter1], y_train[splitter1:]



# Check the dataset sizes

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (12879, 8) (12879, 1) (1431, 8) (1431, 1) (754, 8) (754, 1)

# %% [markdown]
# # new today

# %% [markdown]
# # Model 1 with Relu

# %%
import os

from sklearn.preprocessing import StandardScaler

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Concatenate, Dropout, Dense, GRU

from tensorflow.keras import Model

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

import matplotlib.pyplot as plt



# ... (Code for loading data and other preprocessing steps) ...


# Create a StandardScaler object

scaler = StandardScaler()



# Normalize the training data

X_train_norm = scaler.fit_transform(X_train)

# Normalize the validation data using the same scaler object

X_val_norm = scaler.transform(X_val)

# Normalize the testing data using the same scaler object

X_test_norm = scaler.transform(X_test)



# Define a TCN block with dilations

def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):

    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)

    conv1 = Activation('relu')(conv1)

    return conv1



# Model definition

input_layer = Input(shape=(X_train_norm.shape[1], 1))

l2_strength = 0.001



# TCN block

tcn_blocks = []

for dilation_rate in [1, 2, 4]:

    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)

    tcn_blocks.append(tcn_block)



# Merge TCN blocks

merged = Add()(tcn_blocks)



# GRU layer with regularization and dropout

gru_layer = GRU(32, activation='relu', return_sequences=False,

                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)



# Dense layers

dense1 = Dense(16, activation='relu', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)

dense2 = Dense(8, activation='relu', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)



# Output layer

output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)



# Combine the models

combined_model1 = Model(inputs=input_layer, outputs=output_layer)



# Compile the model with early stopping

opt = Adam(learning_rate=0.01)

combined_model1.compile(optimizer=opt, loss='mae', metrics=['mae'])

early_stopping = EarlyStopping(monitor='val_loss', patience=15)
lronplat = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5)

combined_model1.summary()

 # Train the model

history = combined_model1.fit(X_train_norm, y_train, epochs=100, verbose=1,

                             batch_size=64,

                             validation_data=(X_val_norm, y_val),

                             callbacks=[early_stopping, lronplat])



# Evaluate the model on the test set

y_pred_combined = combined_model1.predict(X_test_norm)

regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values

plt.plot(y_test, label='Actual')

plt.plot(y_pred_combined, label='Predicted')

plt.legend()

plt.show()
# Out:
# Model: "functional_23"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12      │ (None, 8, 1)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_28 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_29 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_30 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 8, 32)     │          0 │ conv1d_28[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 8, 32)     │          0 │ conv1d_29[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 8, 32)     │          0 │ conv1d_30[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 8, 32)     │          0 │ activation_21[0]… │
# │                     │                   │            │ activation_22[0]… │
# │                     │                   │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_12 (GRU)        │ (None, 32)        │      6,336 │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 16)        │        528 │ gru_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 8)         │        136 │ dense_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 1)         │          9 │ dense_32[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,393 (28.88 KB)
#  Trainable params: 7,393 (28.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 261.0479 - mae: 260.9631 - val_loss: 62.7115 - val_mae: 62.5751 - learning_rate: 0.0100
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 69.9069 - mae: 69.7547 - val_loss: 26.4059 - val_mae: 26.2354 - learning_rate: 0.0100
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 31.4324 - mae: 31.2544 - val_loss: 34.3827 - val_mae: 34.1869 - learning_rate: 0.0100
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.0144 - mae: 28.8064 - val_loss: 24.3275 - val_mae: 24.0869 - learning_rate: 0.0100
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 29.2204 - mae: 28.9736 - val_loss: 36.7554 - val_mae: 36.5006 - learning_rate: 0.0100
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 37.0204 - mae: 36.7593 - val_loss: 34.0154 - val_mae: 33.7375 - learning_rate: 0.0100
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 35.4232 - mae: 35.1374 - val_loss: 23.6070 - val_mae: 23.3061 - learning_rate: 0.0100
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 34.9452 - mae: 34.6418 - val_loss: 34.8781 - val_mae: 34.5551 - learning_rate: 0.0100
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 29.8480 - mae: 29.5133 - val_loss: 42.3159 - val_mae: 41.9675 - learning_rate: 0.0100
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 34.1315 - mae: 33.7803 - val_loss: 49.4527 - val_mae: 49.0931 - learning_rate: 0.0100
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 39.5673 - mae: 39.2053 - val_loss: 58.9544 - val_mae: 58.5818 - learning_rate: 0.0100
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 28.6490 - mae: 28.2755 - val_loss: 48.8230 - val_mae: 48.4295 - learning_rate: 0.0100
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11.6597 - mae: 11.2652 - val_loss: 10.5382 - val_mae: 10.1426 - learning_rate: 1.0000e-03
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.4853 - mae: 6.0901 - val_loss: 7.9725 - val_mae: 7.5771 - learning_rate: 1.0000e-03
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6.2845 - mae: 5.8891 - val_loss: 5.8812 - val_mae: 5.4857 - learning_rate: 1.0000e-03
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.8022 - mae: 6.4071 - val_loss: 9.2069 - val_mae: 8.8117 - learning_rate: 1.0000e-03
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.2331 - mae: 5.8381 - val_loss: 10.9616 - val_mae: 10.5660 - learning_rate: 1.0000e-03
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6503 - mae: 6.2555 - val_loss: 4.9661 - val_mae: 4.5720 - learning_rate: 1.0000e-03
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.9547 - mae: 6.5629 - val_loss: 5.8400 - val_mae: 5.4494 - learning_rate: 1.0000e-03
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.4736 - mae: 6.0829 - val_loss: 8.4604 - val_mae: 8.0672 - learning_rate: 1.0000e-03
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.8333 - mae: 5.4407 - val_loss: 10.1711 - val_mae: 9.7803 - learning_rate: 1.0000e-03
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.8355 - mae: 5.4448 - val_loss: 8.0243 - val_mae: 7.6350 - learning_rate: 1.0000e-03
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.3761 - mae: 5.9872 - val_loss: 10.1851 - val_mae: 9.7986 - learning_rate: 1.0000e-03
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.2606 - mae: 4.8740 - val_loss: 8.1590 - val_mae: 7.7725 - learning_rate: 1.0000e-04
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.0614 - mae: 4.6749 - val_loss: 6.7561 - val_mae: 6.3694 - learning_rate: 1.0000e-04
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.0882 - mae: 4.7016 - val_loss: 7.6018 - val_mae: 7.2152 - learning_rate: 1.0000e-04
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.9456 - mae: 4.5591 - val_loss: 7.3390 - val_mae: 6.9525 - learning_rate: 1.0000e-04
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.9320 - mae: 4.5456 - val_loss: 7.8783 - val_mae: 7.4922 - learning_rate: 1.0000e-04
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.9366 - mae: 4.5505 - val_loss: 7.6190 - val_mae: 7.2328 - learning_rate: 1.0000e-05
# Epoch 30/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.7438 - mae: 4.3577 - val_loss: 7.5473 - val_mae: 7.1612 - learning_rate: 1.0000e-05
# Epoch 31/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.1194 - mae: 4.7333 - val_loss: 7.6558 - val_mae: 7.2697 - learning_rate: 1.0000e-05
# Epoch 32/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.9005 - mae: 4.5144 - val_loss: 7.6036 - val_mae: 7.2175 - learning_rate: 1.0000e-05
# Epoch 33/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.9089 - mae: 4.5228 - val_loss: 7.7477 - val_mae: 7.3616 - learning_rate: 1.0000e-05
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Mean Squared Error: 173.7580964302667
# Root Mean Square Error: 13.181733437991632
# Root Mean Square Percentage Error: 29294318239.539684
# Mean Absolute Error: 5.864708044168488
# Mean Absolute Percentage Error: 480460287479971.0

# %% [markdown]
# # Model 1 with own function1

# %%
def custom_activation(x):
    return tf.where(x >= 0, tf.tanh(x), tf.atan(x))

# %%
import os

from sklearn.preprocessing import StandardScaler

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Concatenate, Dropout, Dense, GRU

from tensorflow.keras import Model

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from tensorflow.keras.regularizers import l2

import matplotlib.pyplot as plt



# ... (Code for loading data and other preprocessing steps) ...



# Create a StandardScaler object

scaler = StandardScaler()



# Normalize the training data

X_train_norm = scaler.fit_transform(X_train)

# Normalize the validation data using the same scaler object

X_val_norm = scaler.transform(X_val)

# Normalize the testing data using the same scaler object

X_test_norm = scaler.transform(X_test)



# Define a TCN block with dilations

def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):

    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)

    conv1 = Activation(custom_activation)(conv1)

    return conv1



# Model definition

input_layer = Input(shape=(X_train_norm.shape[1], 1))

l2_strength = 0.001



# TCN block

tcn_blocks = []

for dilation_rate in [1, 2, 4]:

    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)

    tcn_blocks.append(tcn_block)



# Merge TCN blocks

merged = Add()(tcn_blocks)



# GRU layer with regularization and dropout

gru_layer = GRU(32, activation=custom_activation, return_sequences=False,

                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)



# Dense layers

dense1 = Dense(16, activation=custom_activation, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)

dense2 = Dense(8, activation=custom_activation, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)



# Output layer

output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)



# Combine the models

combined_model2 = Model(inputs=input_layer, outputs=output_layer)

# combined_model.summary()



# Compile the model with early stopping

opt = Adam(learning_rate=0.01)

combined_model2.compile(optimizer=opt, loss='mae', metrics=['mae'])

early_stopping = EarlyStopping(monitor='val_loss', patience=25)

combined_model2.summary()
# Train the model

history = combined_model2.fit(X_train_norm, y_train, epochs=100, verbose=1,

                             batch_size=64,

                             validation_data=(X_val_norm, y_val),

                             callbacks=[early_stopping, lronplat])



# Evaluate the model on the test set

y_pred_combined = combined_model2.predict(X_test_norm)

regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values

plt.plot(y_test, label='Actual')

plt.plot(y_pred_combined, label='Predicted')

plt.legend()

plt.show()
# Out:
# Model: "functional_25"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 8, 1)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_31 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_32 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_33 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 8, 32)     │          0 │ conv1d_31[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 8, 32)     │          0 │ conv1d_32[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 8, 32)     │          0 │ conv1d_33[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 8, 32)     │          0 │ activation_24[0]… │
# │                     │                   │            │ activation_25[0]… │
# │                     │                   │            │ activation_26[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_13 (GRU)        │ (None, 32)        │      6,336 │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 16)        │        528 │ gru_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_35 (Dense)    │ (None, 8)         │        136 │ dense_34[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_36 (Dense)    │ (None, 1)         │          9 │ dense_35[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,393 (28.88 KB)
#  Trainable params: 7,393 (28.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 545.8061 - mae: 545.6936 - val_loss: 594.2243 - val_mae: 594.0844 - learning_rate: 0.0100
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 524.9798 - mae: 524.8015 - val_loss: 575.2229 - val_mae: 574.9069 - learning_rate: 0.0100
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 504.1271 - mae: 503.7544 - val_loss: 558.0372 - val_mae: 557.4789 - learning_rate: 0.0100
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 489.4330 - mae: 488.8040 - val_loss: 542.0185 - val_mae: 541.1667 - learning_rate: 0.0100
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 472.0627 - mae: 471.1284 - val_loss: 526.9753 - val_mae: 525.7820 - learning_rate: 0.0100
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 457.7137 - mae: 456.4255 - val_loss: 512.8511 - val_mae: 511.2711 - learning_rate: 0.0100
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 439.7486 - mae: 438.0428 - val_loss: 499.5859 - val_mae: 497.5715 - learning_rate: 0.0100
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 427.5400 - mae: 425.4127 - val_loss: 487.1620 - val_mae: 484.6788 - learning_rate: 0.0100
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 412.8955 - mae: 410.2879 - val_loss: 475.4874 - val_mae: 472.4904 - learning_rate: 0.0100
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 402.1527 - mae: 399.0227 - val_loss: 464.3322 - val_mae: 460.7822 - learning_rate: 0.0100
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 391.3211 - mae: 387.6268 - val_loss: 453.7647 - val_mae: 449.6317 - learning_rate: 0.0100
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 380.0078 - mae: 375.7199 - val_loss: 443.7035 - val_mae: 438.9493 - learning_rate: 0.0100
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 373.9732 - mae: 369.0277 - val_loss: 434.5504 - val_mae: 428.9445 - learning_rate: 0.0100
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 364.5878 - mae: 358.8637 - val_loss: 425.6352 - val_mae: 419.4930 - learning_rate: 0.0100
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 358.0059 - mae: 351.6969 - val_loss: 417.4174 - val_mae: 410.5984 - learning_rate: 0.0100
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 350.6539 - mae: 343.6633 - val_loss: 409.8545 - val_mae: 402.3199 - learning_rate: 0.0100
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 340.6255 - mae: 332.9087 - val_loss: 402.8595 - val_mae: 394.5994 - learning_rate: 0.0100
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 334.5736 - mae: 326.0937 - val_loss: 396.5081 - val_mae: 387.3054 - learning_rate: 0.0100
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 331.2052 - mae: 321.8387 - val_loss: 390.5009 - val_mae: 380.6308 - learning_rate: 0.0100
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 317.7203 - mae: 307.5541 - val_loss: 347.4939 - val_mae: 336.1652 - learning_rate: 0.0100
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 287.5307 - mae: 275.7971 - val_loss: 324.7253 - val_mae: 311.8397 - learning_rate: 0.0100
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 262.7756 - mae: 249.5335 - val_loss: 305.7143 - val_mae: 291.3616 - learning_rate: 0.0100
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 244.3742 - mae: 229.6867 - val_loss: 294.7372 - val_mae: 279.0476 - learning_rate: 0.0100
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 229.6908 - mae: 213.6467 - val_loss: 276.5182 - val_mae: 259.4035 - learning_rate: 0.0100
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 220.6188 - mae: 203.1529 - val_loss: 266.5654 - val_mae: 247.9984 - learning_rate: 0.0100
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 204.2255 - mae: 185.2775 - val_loss: 259.0974 - val_mae: 239.0343 - learning_rate: 0.0100
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 198.7964 - mae: 178.3551 - val_loss: 245.2815 - val_mae: 223.7156 - learning_rate: 0.0100
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 187.6487 - mae: 165.7207 - val_loss: 234.1533 - val_mae: 211.1437 - learning_rate: 0.0100
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 183.3785 - mae: 159.9980 - val_loss: 224.9714 - val_mae: 200.4973 - learning_rate: 0.0100
# Epoch 30/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 172.3564 - mae: 147.5148 - val_loss: 218.5567 - val_mae: 192.6168 - learning_rate: 0.0100
# Epoch 31/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 164.7081 - mae: 138.4055 - val_loss: 210.8558 - val_mae: 183.4597 - learning_rate: 0.0100
# Epoch 32/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 159.4849 - mae: 131.7111 - val_loss: 199.8203 - val_mae: 170.9319 - learning_rate: 0.0100
# Epoch 33/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 154.9062 - mae: 125.6439 - val_loss: 195.5083 - val_mae: 165.1645 - learning_rate: 0.0100
# Epoch 34/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 147.4959 - mae: 116.7872 - val_loss: 188.3934 - val_mae: 156.5809 - learning_rate: 0.0100
# Epoch 35/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 141.5832 - mae: 109.4074 - val_loss: 178.6094 - val_mae: 145.3447 - learning_rate: 0.0100
# Epoch 36/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 138.9522 - mae: 105.3285 - val_loss: 175.7943 - val_mae: 141.1022 - learning_rate: 0.0100
# Epoch 37/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 132.8216 - mae: 97.7739 - val_loss: 168.3144 - val_mae: 132.1547 - learning_rate: 0.0100
# Epoch 38/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 129.9588 - mae: 93.4482 - val_loss: 162.1646 - val_mae: 124.5870 - learning_rate: 0.0100
# Epoch 39/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 125.9230 - mae: 88.0007 - val_loss: 163.4923 - val_mae: 124.5312 - learning_rate: 0.0100
# Epoch 40/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 122.2510 - mae: 82.9554 - val_loss: 152.4822 - val_mae: 112.1815 - learning_rate: 0.0100
# Epoch 41/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 118.9041 - mae: 78.2766 - val_loss: 149.1584 - val_mae: 107.5500 - learning_rate: 0.0100
# Epoch 42/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 118.3075 - mae: 76.3750 - val_loss: 144.3140 - val_mae: 101.4184 - learning_rate: 0.0100
# Epoch 43/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 114.9513 - mae: 71.7257 - val_loss: 145.2614 - val_mae: 101.0353 - learning_rate: 0.0100
# Epoch 44/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 111.7629 - mae: 67.2187 - val_loss: 140.9749 - val_mae: 95.4364 - learning_rate: 0.0100
# Epoch 45/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 109.1830 - mae: 63.3272 - val_loss: 134.7580 - val_mae: 87.9396 - learning_rate: 0.0100
# Epoch 46/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 106.8920 - mae: 59.7774 - val_loss: 130.9165 - val_mae: 82.9101 - learning_rate: 0.0100
# Epoch 47/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 105.0280 - mae: 56.7392 - val_loss: 129.1088 - val_mae: 79.9416 - learning_rate: 0.0100
# Epoch 48/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 104.3752 - mae: 54.9208 - val_loss: 127.8524 - val_mae: 77.5892 - learning_rate: 0.0100
# Epoch 49/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 101.7485 - mae: 51.2260 - val_loss: 123.9168 - val_mae: 72.6123 - learning_rate: 0.0100
# Epoch 50/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 101.6774 - mae: 50.1205 - val_loss: 127.5751 - val_mae: 75.2724 - learning_rate: 0.0100
# Epoch 51/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 100.5956 - mae: 48.0314 - val_loss: 117.2132 - val_mae: 63.9235 - learning_rate: 0.0100
# Epoch 52/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 98.6281 - mae: 45.1040 - val_loss: 114.0656 - val_mae: 59.8565 - learning_rate: 0.0100
# Epoch 53/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 97.0882 - mae: 42.6669 - val_loss: 111.9141 - val_mae: 56.8394 - learning_rate: 0.0100
# Epoch 54/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 96.2271 - mae: 40.9451 - val_loss: 111.6742 - val_mae: 55.7686 - learning_rate: 0.0100
# Epoch 55/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 94.8347 - mae: 38.7382 - val_loss: 110.2291 - val_mae: 53.5479 - learning_rate: 0.0100
# Epoch 56/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 94.9499 - mae: 38.0755 - val_loss: 112.3541 - val_mae: 54.9219 - learning_rate: 0.0100
# Epoch 57/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 94.7928 - mae: 37.1881 - val_loss: 108.5386 - val_mae: 50.3849 - learning_rate: 0.0100
# Epoch 58/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 93.8516 - mae: 35.5298 - val_loss: 107.1813 - val_mae: 48.3536 - learning_rate: 0.0100
# Epoch 59/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 94.3568 - mae: 35.3599 - val_loss: 104.8624 - val_mae: 45.4112 - learning_rate: 0.0100
# Epoch 60/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 94.8395 - mae: 35.2385 - val_loss: 107.0171 - val_mae: 47.0103 - learning_rate: 0.0100
# Epoch 61/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 92.4064 - mae: 32.2713 - val_loss: 103.3304 - val_mae: 42.7862 - learning_rate: 0.0100
# Epoch 62/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 92.8351 - mae: 32.1612 - val_loss: 107.0236 - val_mae: 45.9786 - learning_rate: 0.0100
# Epoch 63/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 91.7550 - mae: 30.5904 - val_loss: 102.3369 - val_mae: 40.7988 - learning_rate: 0.0100
# Epoch 64/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 92.0678 - mae: 30.4144 - val_loss: 102.4808 - val_mae: 40.4824 - learning_rate: 0.0100
# Epoch 65/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 91.3256 - mae: 29.2118 - val_loss: 102.5177 - val_mae: 40.0826 - learning_rate: 0.0100
# Epoch 66/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 90.9381 - mae: 28.4052 - val_loss: 104.1912 - val_mae: 41.3680 - learning_rate: 0.0100
# Epoch 67/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 90.5275 - mae: 27.6234 - val_loss: 101.2795 - val_mae: 38.0792 - learning_rate: 0.0100
# Epoch 68/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 91.2118 - mae: 27.9207 - val_loss: 101.4628 - val_mae: 37.9078 - learning_rate: 0.0100
# Epoch 69/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 91.4543 - mae: 27.8169 - val_loss: 99.0299 - val_mae: 35.1697 - learning_rate: 0.0100
# Epoch 70/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 90.0297 - mae: 26.1103 - val_loss: 99.6614 - val_mae: 35.5007 - learning_rate: 0.0100
# Epoch 71/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 90.9349 - mae: 26.7075 - val_loss: 102.2149 - val_mae: 37.7669 - learning_rate: 0.0100
# Epoch 72/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 89.6927 - mae: 25.1752 - val_loss: 98.2070 - val_mae: 33.4740 - learning_rate: 0.0100
# Epoch 73/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 89.8335 - mae: 25.0356 - val_loss: 101.1848 - val_mae: 36.2047 - learning_rate: 0.0100
# Epoch 74/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 90.9704 - mae: 25.9368 - val_loss: 98.4727 - val_mae: 33.2705 - learning_rate: 0.0100
# Epoch 75/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 89.1550 - mae: 23.9017 - val_loss: 97.6125 - val_mae: 32.1659 - learning_rate: 0.0100
# Epoch 76/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 88.7932 - mae: 23.2958 - val_loss: 97.0933 - val_mae: 31.3800 - learning_rate: 0.0100
# Epoch 77/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 89.4422 - mae: 23.6664 - val_loss: 98.5029 - val_mae: 32.5651 - learning_rate: 0.0100
# Epoch 78/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 89.8320 - mae: 23.8355 - val_loss: 98.3900 - val_mae: 32.2944 - learning_rate: 0.0100
# Epoch 79/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 88.8075 - mae: 22.6651 - val_loss: 97.5105 - val_mae: 31.2443 - learning_rate: 0.0100
# Epoch 80/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 89.0456 - mae: 22.7506 - val_loss: 100.2990 - val_mae: 33.8934 - learning_rate: 0.0100
# Epoch 81/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 90.7103 - mae: 24.2595 - val_loss: 98.8626 - val_mae: 32.3065 - learning_rate: 0.0100
# Epoch 82/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 87.5595 - mae: 21.0025 - val_loss: 95.0504 - val_mae: 28.4857 - learning_rate: 1.0000e-03
# Epoch 83/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 86.4362 - mae: 19.8669 - val_loss: 95.7011 - val_mae: 29.1205 - learning_rate: 1.0000e-03
# Epoch 84/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 85.4775 - mae: 18.8942 - val_loss: 95.7619 - val_mae: 29.1642 - learning_rate: 1.0000e-03
# Epoch 85/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 86.0535 - mae: 19.4514 - val_loss: 96.2428 - val_mae: 29.6271 - learning_rate: 1.0000e-03
# Epoch 86/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.6033 - mae: 18.9829 - val_loss: 95.4970 - val_mae: 28.8615 - learning_rate: 1.0000e-03
# Epoch 87/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 85.7781 - mae: 19.1381 - val_loss: 96.3009 - val_mae: 29.6456 - learning_rate: 1.0000e-03
# Epoch 88/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 86.2407 - mae: 19.5847 - val_loss: 95.3869 - val_mae: 28.7295 - learning_rate: 1.0000e-04
# Epoch 89/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.6812 - mae: 19.0232 - val_loss: 95.2487 - val_mae: 28.5892 - learning_rate: 1.0000e-04
# Epoch 90/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.9865 - mae: 19.3265 - val_loss: 95.3540 - val_mae: 28.6922 - learning_rate: 1.0000e-04
# Epoch 91/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 85.4912 - mae: 18.8289 - val_loss: 95.2523 - val_mae: 28.5882 - learning_rate: 1.0000e-04
# Epoch 92/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.6827 - mae: 19.0180 - val_loss: 95.2421 - val_mae: 28.5756 - learning_rate: 1.0000e-04
# Epoch 93/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.6334 - mae: 18.9668 - val_loss: 95.3095 - val_mae: 28.6428 - learning_rate: 1.0000e-05
# Epoch 94/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 85.5445 - mae: 18.8779 - val_loss: 95.3307 - val_mae: 28.6639 - learning_rate: 1.0000e-05
# Epoch 95/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 85.1601 - mae: 18.4934 - val_loss: 95.2883 - val_mae: 28.6214 - learning_rate: 1.0000e-05
# Epoch 96/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 84.9899 - mae: 18.3230 - val_loss: 95.3127 - val_mae: 28.6457 - learning_rate: 1.0000e-05
# Epoch 97/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 85.2058 - mae: 18.5389 - val_loss: 95.3876 - val_mae: 28.7205 - learning_rate: 1.0000e-05
# Epoch 98/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 85.6293 - mae: 18.9622 - val_loss: 95.3214 - val_mae: 28.6543 - learning_rate: 1.0000e-06
# Epoch 99/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 85.5346 - mae: 18.8675 - val_loss: 95.3231 - val_mae: 28.6560 - learning_rate: 1.0000e-06
# Epoch 100/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.1756 - mae: 18.5085 - val_loss: 95.3393 - val_mae: 28.6722 - learning_rate: 1.0000e-06
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Mean Squared Error: 24.654591766923303
# Root Mean Square Error: 4.96533903846689
# Root Mean Square Percentage Error: 514573868.9426196
# Mean Absolute Error: 4.7558883747940675
# Mean Absolute Percentage Error: 8439599344153.833

# %% [markdown]
# # model 1 with own function 2

# %%
def custom_act(x):
    return tf.where(x>=0, x, tf.tanh(x)+tf.atan(x))

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Activation, Add, GRU, Dense, Dropout
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

# Placeholder: Load your data (ensure X_train, X_val, X_test, y_train, y_val, y_test are defined)
# For example:
# X_train, X_val, X_test = <your_data_splits>
# y_train, y_val, y_test = <your_labels>

# Normalize the data
scaler = StandardScaler()
X_train_norm = scaler.fit_transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# Define your custom activation function
def custom_act(x):
    return tf.where(x >= 0, x, tf.tanh(x) + tf.atan(x))

# Define a TCN block with dilations
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate, dropout_rate=0.2):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation(custom_act)(conv1)  # Use custom activation here
    conv1 = Dropout(dropout_rate)(conv1)
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks
tcn_blocks = []
for dilation_rate in [1, 2, 4]:  # Add more dilation rates if needed
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with custom activation and dropout
gru_layer = GRU(32, activation=custom_act, return_sequences=False,
                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)

# Dense layers
dense1 = Dense(16, activation=custom_act, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense2 = Dense(8, activation=custom_act, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine the models
combined_model1 = Model(inputs=input_layer, outputs=output_layer)

# Compile the model with early stopping
opt = Adam(learning_rate=0.01)
combined_model1.compile(optimizer=opt, loss='mae', metrics=['mae'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lronplat = ReduceLROnPlateau(monitor='val_loss', patience=5)

# Model summary
combined_model1.summary()

# Train the model
history = combined_model1.fit(
    X_train_norm, y_train,
    epochs=100,
    verbose=1,
    batch_size=64,
    validation_data=(X_val_norm, y_val),
    callbacks=[early_stopping, lronplat]
)

# Evaluate the model on the test set
y_pred_combined = combined_model1.predict(X_test_norm)

# Define regression metrics
def regression_metrics(y_true, y_pred):
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"Mean Squared Error: {mse}")
    print(f"Root Mean Square Error: {rmse}")
    print(f"Mean Absolute Error: {mae}")
    print(f"Mean Absolute Percentage Error: {mape}")
    print(f"R2 Score: {r2}")

regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual', alpha=0.7)
plt.plot(y_pred_combined, label='Predicted', alpha=0.7)
plt.title('TCN-GRU Model with Custom Activation: Actual vs Predicted')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 8, 1)           │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 8, 32)          │            128 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 8, 32)          │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 8, 32)          │              0 │ conv1d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 8, 32)          │              0 │ conv1d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 8, 32)          │              0 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 8, 32)          │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 8, 32)          │              0 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 8, 32)          │              0 │ dropout[0][0],         │
# │                           │                        │                │ dropout_1[0][0],       │
# │                           │                        │                │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru (GRU)                 │ (None, 32)             │          6,336 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 16)             │            528 │ gru[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 8)              │            136 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │              9 │ dense_1[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,393 (28.88 KB)
#  Trainable params: 7,393 (28.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - loss: 208.6068 - mae: 208.4120 - val_loss: 26.2722 - val_mae: 25.9949 - learning_rate: 0.0100
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 24.9489 - mae: 24.6523 - val_loss: 39.7817 - val_mae: 39.4349 - learning_rate: 0.0100
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 24.9790 - mae: 24.6165 - val_loss: 33.7510 - val_mae: 33.3626 - learning_rate: 0.0100
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 21.0808 - mae: 20.6729 - val_loss: 24.9101 - val_mae: 24.4522 - learning_rate: 0.0100
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 21.5315 - mae: 21.0707 - val_loss: 23.2624 - val_mae: 22.7871 - learning_rate: 0.0100
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 24.4318 - mae: 23.9513 - val_loss: 7.1538 - val_mae: 6.6338 - learning_rate: 0.0100
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 16.2838 - mae: 15.7555 - val_loss: 38.1465 - val_mae: 37.5869 - learning_rate: 0.0100
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 20.8203 - mae: 20.2500 - val_loss: 10.3851 - val_mae: 9.8108 - learning_rate: 0.0100
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 22.2051 - mae: 21.6088 - val_loss: 29.3290 - val_mae: 28.6378 - learning_rate: 0.0100
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 18.2107 - mae: 17.5159 - val_loss: 18.1135 - val_mae: 17.4285 - learning_rate: 0.0100
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 25.4272 - mae: 24.7396 - val_loss: 29.9190 - val_mae: 29.2329 - learning_rate: 0.0100
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 14.9586 - mae: 14.2736 - val_loss: 7.9581 - val_mae: 7.2743 - learning_rate: 1.0000e-03
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 12.0064 - mae: 11.3233 - val_loss: 15.8550 - val_mae: 15.1746 - learning_rate: 1.0000e-03
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 12.1759 - mae: 11.4964 - val_loss: 5.2648 - val_mae: 4.5874 - learning_rate: 1.0000e-03
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 11.5759 - mae: 10.8995 - val_loss: 6.7848 - val_mae: 6.1114 - learning_rate: 1.0000e-03
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 11.5875 - mae: 10.9151 - val_loss: 6.7063 - val_mae: 6.0369 - learning_rate: 1.0000e-03
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 11.3664 - mae: 10.6982 - val_loss: 14.7317 - val_mae: 14.0667 - learning_rate: 1.0000e-03
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 11.9886 - mae: 11.3245 - val_loss: 6.4007 - val_mae: 5.7402 - learning_rate: 1.0000e-03
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 11.3423 - mae: 10.6828 - val_loss: 5.2351 - val_mae: 4.5790 - learning_rate: 1.0000e-03
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 11.3736 - mae: 10.7188 - val_loss: 10.1099 - val_mae: 9.4576 - learning_rate: 1.0000e-03
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.2595 - mae: 10.6088 - val_loss: 4.4203 - val_mae: 3.7730 - learning_rate: 1.0000e-03
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 11.4288 - mae: 10.7827 - val_loss: 7.0145 - val_mae: 6.3721 - learning_rate: 1.0000e-03
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 11.0211 - mae: 10.3796 - val_loss: 15.5089 - val_mae: 14.8714 - learning_rate: 1.0000e-03
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 11.3914 - mae: 10.7547 - val_loss: 8.0642 - val_mae: 7.4303 - learning_rate: 1.0000e-03
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.7141 - mae: 10.0816 - val_loss: 7.2885 - val_mae: 6.6602 - learning_rate: 1.0000e-03
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 10.4537 - mae: 9.8264 - val_loss: 7.0975 - val_mae: 6.4732 - learning_rate: 1.0000e-03
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 10.4940 - mae: 9.8699 - val_loss: 6.3166 - val_mae: 5.6929 - learning_rate: 1.0000e-04
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 10.1888 - mae: 9.5652 - val_loss: 6.4089 - val_mae: 5.7856 - learning_rate: 1.0000e-04
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 10.2940 - mae: 9.6708 - val_loss: 6.6082 - val_mae: 5.9855 - learning_rate: 1.0000e-04
# Epoch 30/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 10.0115 - mae: 9.3890 - val_loss: 8.0118 - val_mae: 7.3899 - learning_rate: 1.0000e-04
# Epoch 31/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 10.0162 - mae: 9.3944 - val_loss: 6.1349 - val_mae: 5.5136 - learning_rate: 1.0000e-04
# Epoch 32/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 10.1099 - mae: 9.4886 - val_loss: 7.7215 - val_mae: 7.1003 - learning_rate: 1.0000e-05
# Epoch 33/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 10.0480 - mae: 9.4269 - val_loss: 7.4352 - val_mae: 6.8141 - learning_rate: 1.0000e-05
# Epoch 34/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 9.9875 - mae: 9.3664 - val_loss: 6.6511 - val_mae: 6.0301 - learning_rate: 1.0000e-05
# Epoch 35/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 10.0423 - mae: 9.4213 - val_loss: 7.5232 - val_mae: 6.9023 - learning_rate: 1.0000e-05
# Epoch 36/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 10.1097 - mae: 9.4888 - val_loss: 7.5670 - val_mae: 6.9462 - learning_rate: 1.0000e-05
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# <ipython-input-24-598ed3c5410d>:90: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Mean Squared Error: 83.98935330305139
# Root Mean Square Error: 9.164570546569621
# Mean Absolute Error: 2.647822058801626
# Mean Absolute Percentage Error: inf
# R2 Score: 0.9984625577926636

# %% [markdown]
# # Model 1 with elu

# %%
import os
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Dropout, Dense, GRU
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Function to calculate and display regression metrics
def regression_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    print(f"Mean Squared Error: {mse}")
    print(f"Root Mean Squared Error: {rmse}")
    print(f"Mean Absolute Error: {mae}")

# Assume `X_train`, `X_val`, `X_test`, `y_train`, `y_val`, `y_test` are preloaded

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Define a TCN block with dilations
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation("elu")(conv1)  # Apply ELU activation
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks with different dilation rates
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with ELU activation, regularization, and dropout
gru_layer = GRU(32, return_sequences=False,
                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)
gru_layer = Activation("elu")(gru_layer)  # Apply ELU activation

# Dense layers with ELU activation
dense1 = Dense(16, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Activation("elu")(dense1)  # Apply ELU activation

dense2 = Dense(8, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Activation("elu")(dense2)  # Apply ELU activation

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine the models
combined_model1 = Model(inputs=input_layer, outputs=output_layer)
combined_model1.summary()

# Compile the model with early stopping and learning rate reduction
opt = Adam(learning_rate=0.01)
combined_model1.compile(optimizer=opt, loss='mae', metrics=['mae'])
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lronplat = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5)

# Train the model
history = combined_model1.fit(X_train_norm, y_train, epochs=100, verbose=1,
                              batch_size=64,
                              validation_data=(X_val_norm, y_val),
                              callbacks=[early_stopping, lronplat])

# Evaluate the model on the test set
y_pred_combined = combined_model1.predict(X_test_norm)

# Display regression metrics
regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.title("Actual vs Predicted Values")
plt.xlabel("Samples")
plt.ylabel("Value")
plt.show()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 8, 1)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_3 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_4 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_5 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 8, 32)          │              0 │ conv1d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 8, 32)          │              0 │ conv1d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 8, 32)          │              0 │ conv1d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 8, 32)          │              0 │ activation_6[0][0],    │
# │                           │                        │                │ activation_7[0][0],    │
# │                           │                        │                │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_1 (GRU)               │ (None, 32)             │          6,336 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32)             │              0 │ gru_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 16)             │            528 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 16)             │              0 │ dense_3[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 8)              │            136 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 8)              │              0 │ dense_4[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1)              │              9 │ activation_11[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,393 (28.88 KB)
#  Trainable params: 7,393 (28.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 344.1884 - mae: 343.9025 - val_loss: 39.9286 - val_mae: 39.3361 - learning_rate: 0.0100
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 23.5843 - mae: 22.9700 - val_loss: 24.3535 - val_mae: 23.6933 - learning_rate: 0.0100
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 15.9397 - mae: 15.2674 - val_loss: 17.7355 - val_mae: 17.0281 - learning_rate: 0.0100
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 12.9945 - mae: 12.2798 - val_loss: 15.7137 - val_mae: 14.9860 - learning_rate: 0.0100
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 12.7074 - mae: 11.9738 - val_loss: 13.3463 - val_mae: 12.5907 - learning_rate: 0.0100
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 10.3615 - mae: 9.6025 - val_loss: 13.9512 - val_mae: 13.1851 - learning_rate: 0.0100
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 10.9513 - mae: 10.1833 - val_loss: 11.6248 - val_mae: 10.8359 - learning_rate: 0.0100
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.2469 - mae: 10.4416 - val_loss: 10.1755 - val_mae: 9.3481 - learning_rate: 0.0100
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 9.5624 - mae: 8.7295 - val_loss: 14.9328 - val_mae: 14.0986 - learning_rate: 0.0100
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 10.4189 - mae: 9.5783 - val_loss: 9.6883 - val_mae: 8.8358 - learning_rate: 0.0100
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.8646 - mae: 8.0073 - val_loss: 9.4552 - val_mae: 8.6018 - learning_rate: 0.0100
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 9.4569 - mae: 8.5972 - val_loss: 16.2244 - val_mae: 15.3627 - learning_rate: 0.0100
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 8.9658 - mae: 8.1034 - val_loss: 9.2898 - val_mae: 8.4244 - learning_rate: 0.0100
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 7.7330 - mae: 6.8671 - val_loss: 14.3049 - val_mae: 13.4410 - learning_rate: 0.0100
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.0337 - mae: 7.1658 - val_loss: 10.4225 - val_mae: 9.5484 - learning_rate: 0.0100
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.9044 - mae: 8.0326 - val_loss: 7.9873 - val_mae: 7.1202 - learning_rate: 0.0100
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 9.1145 - mae: 8.2506 - val_loss: 12.6838 - val_mae: 11.8193 - learning_rate: 0.0100
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.1823 - mae: 7.3183 - val_loss: 8.6649 - val_mae: 7.7940 - learning_rate: 0.0100
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.1955 - mae: 7.3218 - val_loss: 6.7477 - val_mae: 5.8689 - learning_rate: 0.0100
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 7.6881 - mae: 6.8103 - val_loss: 11.9884 - val_mae: 11.1080 - learning_rate: 0.0100
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 10.2777 - mae: 9.3983 - val_loss: 9.9756 - val_mae: 9.0857 - learning_rate: 0.0100
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 7.6714 - mae: 6.7781 - val_loss: 7.6301 - val_mae: 6.7457 - learning_rate: 0.0100
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 7.0010 - mae: 6.1205 - val_loss: 8.3539 - val_mae: 7.4820 - learning_rate: 0.0050
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 6.0116 - mae: 5.1436 - val_loss: 4.7328 - val_mae: 3.8746 - learning_rate: 0.0050
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 6.4122 - mae: 5.5563 - val_loss: 8.7589 - val_mae: 7.9073 - learning_rate: 0.0050
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 6.5799 - mae: 5.7310 - val_loss: 11.4120 - val_mae: 10.5648 - learning_rate: 0.0050
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.8186 - mae: 5.9728 - val_loss: 5.7598 - val_mae: 4.9217 - learning_rate: 0.0050
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 5.7497 - mae: 4.9135 - val_loss: 8.4105 - val_mae: 7.5798 - learning_rate: 0.0025
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 5.3871 - mae: 4.5577 - val_loss: 6.2538 - val_mae: 5.4272 - learning_rate: 0.0025
# Epoch 30/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.5114 - mae: 4.6865 - val_loss: 7.9698 - val_mae: 7.1490 - learning_rate: 0.0025
# Epoch 31/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.9956 - mae: 4.1757 - val_loss: 7.8250 - val_mae: 7.0079 - learning_rate: 0.0012
# Epoch 32/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 5.0462 - mae: 4.2298 - val_loss: 7.7760 - val_mae: 6.9620 - learning_rate: 0.0012
# Epoch 33/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.9888 - mae: 4.1754 - val_loss: 6.5249 - val_mae: 5.7143 - learning_rate: 0.0012
# Epoch 34/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 4.7128 - mae: 3.9027 - val_loss: 7.2484 - val_mae: 6.4394 - learning_rate: 6.2500e-04
# Epoch 35/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 4.7085 - mae: 3.9002 - val_loss: 7.3838 - val_mae: 6.5766 - learning_rate: 6.2500e-04
# Epoch 36/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 4.6295 - mae: 3.8229 - val_loss: 7.3279 - val_mae: 6.5233 - learning_rate: 6.2500e-04
# Epoch 37/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 4.5647 - mae: 3.7603 - val_loss: 7.3013 - val_mae: 6.4974 - learning_rate: 3.1250e-04
# Epoch 38/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.4507 - mae: 3.6471 - val_loss: 7.4796 - val_mae: 6.6768 - learning_rate: 3.1250e-04
# Epoch 39/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.5752 - mae: 3.7726 - val_loss: 7.2353 - val_mae: 6.4336 - learning_rate: 3.1250e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Mean Squared Error: 196.43295347802166
# Root Mean Squared Error: 14.015454094606485
# Mean Absolute Error: 5.075830654060809

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Dense, GRU
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# Function to calculate and display regression metrics
def regression_metrics(y_true, y_pred):
    # Handle zero values to prevent division by zero
    epsilon = 1e-10  # Small constant to avoid divide by zero errors
    y_true_safe = np.where(y_true == 0, epsilon, y_true)  # Replace 0 with epsilon

    mse = np.mean((y_true - y_pred) ** 2)
    rmse = np.sqrt(mse)
    rmspe = np.sqrt(np.mean(((y_true - y_pred) / y_true_safe) ** 2)) * 100
    mae = np.mean(np.abs(y_true - y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / y_true_safe)) * 100

    print(f"Mean Squared Error: {mse}")
    print(f"Root Mean Square Error: {rmse}")
    print(f"Root Mean Square Percentage Error: {rmspe}")
    print(f"Mean Absolute Error: {mae}")
    print(f"Mean Absolute Percentage Error: {mape}")

# ... (Code for loading data and other preprocessing steps) ...

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# Define a TCN block with dilations
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation("elu")(conv1)  # Use ELU activation
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks with different dilation rates
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with ELU activation, regularization, and dropout
gru_layer = GRU(32, return_sequences=False,
                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)
gru_layer = Activation("elu")(gru_layer)  # Use ELU activation

# Dense layers with ELU activation
dense1 = Dense(16, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Activation("elu")(dense1)  # Use ELU activation

dense2 = Dense(8, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Activation("elu")(dense2)  # Use ELU activation

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine the models
combined_model1 = Model(inputs=input_layer, outputs=output_layer)
combined_model1.summary()

# Compile the model with early stopping
opt = Adam(learning_rate=0.01)
combined_model1.compile(optimizer=opt, loss='mae', metrics=['mae'])
early_stopping = EarlyStopping(monitor='val_loss', patience=15)
lronplat = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3)

# Train the model
history = combined_model1.fit(X_train_norm, y_train, epochs=100, verbose=1,
                              batch_size=64,
                              validation_data=(X_val_norm, y_val),
                              callbacks=[early_stopping, lronplat])

# Evaluate the model on the test set
y_pred_combined = combined_model1.predict(X_test_norm).flatten()

# Calculate and display regression metrics
regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.show()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4             │ (None, 8, 1)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_3 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_4 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_5 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 8, 32)          │              0 │ conv1d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 8, 32)          │              0 │ conv1d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 8, 32)          │              0 │ conv1d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 8, 32)          │              0 │ activation_6[0][0],    │
# │                           │                        │                │ activation_7[0][0],    │
# │                           │                        │                │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_10 (GRU)              │ (None, 32)             │          6,336 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32)             │              0 │ gru_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 16)             │            528 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 16)             │              0 │ dense_12[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 8)              │            136 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 8)              │              0 │ dense_13[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 1)              │              9 │ activation_11[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,393 (28.88 KB)
#  Trainable params: 7,393 (28.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 395.7471 - mae: 395.4630 - val_loss: 37.9736 - val_mae: 37.2182 - learning_rate: 0.0100
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 37.0371 - mae: 36.2297 - val_loss: 31.7382 - val_mae: 30.8200 - learning_rate: 0.0100
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 18.8231 - mae: 17.8904 - val_loss: 33.2393 - val_mae: 32.2817 - learning_rate: 0.0100
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 16.3909 - mae: 15.4267 - val_loss: 31.1114 - val_mae: 30.1346 - learning_rate: 0.0100
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 15.1432 - mae: 14.1647 - val_loss: 20.3319 - val_mae: 19.3472 - learning_rate: 0.0100
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 14.1567 - mae: 13.1647 - val_loss: 14.5292 - val_mae: 13.5225 - learning_rate: 0.0100
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 13.1146 - mae: 12.0996 - val_loss: 13.5247 - val_mae: 12.5051 - learning_rate: 0.0100
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 12.1920 - mae: 11.1765 - val_loss: 19.0738 - val_mae: 18.0516 - learning_rate: 0.0100
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 11.5195 - mae: 10.4890 - val_loss: 22.2296 - val_mae: 21.1868 - learning_rate: 0.0100
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 11.4952 - mae: 10.4501 - val_loss: 24.6381 - val_mae: 23.5896 - learning_rate: 0.0100
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 8.6687 - mae: 7.6199 - val_loss: 14.3323 - val_mae: 13.2850 - learning_rate: 1.0000e-03
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 7.5603 - mae: 6.5140 - val_loss: 13.8045 - val_mae: 12.7599 - learning_rate: 1.0000e-03
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 7.3695 - mae: 6.3255 - val_loss: 15.0504 - val_mae: 14.0075 - learning_rate: 1.0000e-03
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.1665 - mae: 6.1236 - val_loss: 14.4079 - val_mae: 13.3654 - learning_rate: 1.0000e-04
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 6.8905 - mae: 5.8480 - val_loss: 14.1049 - val_mae: 13.0627 - learning_rate: 1.0000e-04
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 6.8498 - mae: 5.8077 - val_loss: 13.9718 - val_mae: 12.9300 - learning_rate: 1.0000e-04
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 6.9445 - mae: 5.9027 - val_loss: 14.0125 - val_mae: 12.9707 - learning_rate: 1.0000e-05
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 6.9643 - mae: 5.9225 - val_loss: 14.0521 - val_mae: 13.0103 - learning_rate: 1.0000e-05
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 6.9372 - mae: 5.8955 - val_loss: 13.9877 - val_mae: 12.9460 - learning_rate: 1.0000e-05
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 6.8334 - mae: 5.7917 - val_loss: 13.9754 - val_mae: 12.9337 - learning_rate: 1.0000e-06
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 6.8614 - mae: 5.8197 - val_loss: 13.9492 - val_mae: 12.9075 - learning_rate: 1.0000e-06
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 6.8977 - mae: 5.8560 - val_loss: 13.9503 - val_mae: 12.9086 - learning_rate: 1.0000e-06
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Mean Squared Error: 107583.07827003225
# Root Mean Square Error: 327.9985949208201
# Root Mean Square Percentage Error: 16696671122244.486
# Mean Absolute Error: 267.7180564169609
# Mean Absolute Percentage Error: 526028133417.3406

# %% [markdown]
# # Model 1 with Selu

# %%
import tensorflow as tf

def selu(x):
    alpha = 1.67326
    scale = 1.0507
    return scale * tf.where(x > 0, x, alpha * (tf.exp(x) - 1))

# %%
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model

input_layer = Input(shape=(10,))
dense_layer = Dense(64, activation=selu)(input_layer)
model = Model(inputs=input_layer, outputs=dense_layer)

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Concatenate, Dropout, Dense, GRU
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

# ... (Code for loading data and other preprocessing steps) ...

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# Define a TCN block with dilations
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation("selu")(conv1)  # Replace Trh() with SELU activation
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks with different dilation rates
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with SELU activation, regularization, and dropout
gru_layer = GRU(32, return_sequences=False,
                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)
gru_layer = Activation("selu")(gru_layer)  # Replace Trh() with SELU activation

# Dense layers with SELU activation
dense1 = Dense(16, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Activation("selu")(dense1)  # Replace Trh() with SELU activation

dense2 = Dense(8, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Activation("selu")(dense2)  # Replace Trh() with SELU activation

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine the models
combined_model1 = Model(inputs=input_layer, outputs=output_layer)
combined_model1.summary()

# Compile the model with early stopping
opt = Adam(learning_rate=0.01)
combined_model1.compile(optimizer=opt, loss='mae', metrics=['mae'])
early_stopping = EarlyStopping(monitor='val_loss', patience=15)
lronplat = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3)

# Train the model
history = combined_model1.fit(X_train_norm, y_train, epochs=100, verbose=1,
                              batch_size=64,
                              validation_data=(X_val_norm, y_val),
                              callbacks=[early_stopping, lronplat])

# Evaluate the model on the test set
y_pred_combined = combined_model1.predict(X_test_norm)

# Function to calculate and display regression metrics
regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.show()
# Out:
# Model: "functional_29"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_15      │ (None, 8, 1)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_34 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_35 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_36 (Conv1D)  │ (None, 8, 32)     │        128 │ input_layer_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 8, 32)     │          0 │ conv1d_34[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 8, 32)     │          0 │ conv1d_35[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 8, 32)     │          0 │ conv1d_36[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 8, 32)     │          0 │ activation_27[0]… │
# │                     │                   │            │ activation_28[0]… │
# │                     │                   │            │ activation_29[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_14 (GRU)        │ (None, 32)        │      6,336 │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 32)        │          0 │ gru_14[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 16)        │        528 │ activation_30[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 16)        │          0 │ dense_38[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 8)         │        136 │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 8)         │          0 │ dense_39[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_40 (Dense)    │ (None, 1)         │          9 │ activation_32[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,393 (28.88 KB)
#  Trainable params: 7,393 (28.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 374.2512 - mae: 373.9907 - val_loss: 29.1808 - val_mae: 28.5440 - learning_rate: 0.0100
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 26.1926 - mae: 25.5256 - val_loss: 16.2842 - val_mae: 15.5434 - learning_rate: 0.0100
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 17.6324 - mae: 16.8749 - val_loss: 16.5499 - val_mae: 15.7473 - learning_rate: 0.0100
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 14.7797 - mae: 13.9660 - val_loss: 24.8819 - val_mae: 24.0293 - learning_rate: 0.0100
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 13.2609 - mae: 12.4060 - val_loss: 19.3552 - val_mae: 18.4930 - learning_rate: 0.0100
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.9068 - mae: 8.0450 - val_loss: 15.3710 - val_mae: 14.5102 - learning_rate: 1.0000e-03
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.5647 - mae: 7.7047 - val_loss: 16.4232 - val_mae: 15.5644 - learning_rate: 1.0000e-03
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.8532 - mae: 6.9948 - val_loss: 16.4704 - val_mae: 15.6136 - learning_rate: 1.0000e-03
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.8534 - mae: 6.9964 - val_loss: 14.5124 - val_mae: 13.6572 - learning_rate: 1.0000e-03
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.7177 - mae: 6.8629 - val_loss: 12.7130 - val_mae: 11.8596 - learning_rate: 1.0000e-03
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.4467 - mae: 6.5939 - val_loss: 16.7464 - val_mae: 15.8942 - learning_rate: 1.0000e-03
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.4139 - mae: 6.5622 - val_loss: 11.9320 - val_mae: 11.0816 - learning_rate: 1.0000e-03
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.1200 - mae: 6.2700 - val_loss: 12.1770 - val_mae: 11.3284 - learning_rate: 1.0000e-03
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6913 - mae: 5.8429 - val_loss: 8.9453 - val_mae: 8.0977 - learning_rate: 1.0000e-03
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.8344 - mae: 5.9869 - val_loss: 11.0978 - val_mae: 10.2505 - learning_rate: 1.0000e-03
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.4566 - mae: 5.6093 - val_loss: 11.9297 - val_mae: 11.0828 - learning_rate: 1.0000e-03
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.4432 - mae: 5.5962 - val_loss: 11.2072 - val_mae: 10.3605 - learning_rate: 1.0000e-03
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.5340 - mae: 4.6873 - val_loss: 9.5708 - val_mae: 8.7241 - learning_rate: 1.0000e-04
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.5836 - mae: 4.7369 - val_loss: 9.8021 - val_mae: 8.9555 - learning_rate: 1.0000e-04
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4392 - mae: 4.5926 - val_loss: 10.3562 - val_mae: 9.5098 - learning_rate: 1.0000e-04
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.5873 - mae: 4.7409 - val_loss: 9.6502 - val_mae: 8.8038 - learning_rate: 1.0000e-05
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.5587 - mae: 4.7123 - val_loss: 9.6302 - val_mae: 8.7837 - learning_rate: 1.0000e-05
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.6386 - mae: 4.7922 - val_loss: 9.6058 - val_mae: 8.7594 - learning_rate: 1.0000e-05
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.5404 - mae: 4.6939 - val_loss: 9.6688 - val_mae: 8.8224 - learning_rate: 1.0000e-06
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 5.5700 - mae: 4.7236 - val_loss: 9.6864 - val_mae: 8.8400 - learning_rate: 1.0000e-06
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.5668 - mae: 4.7204 - val_loss: 9.6942 - val_mae: 8.8478 - learning_rate: 1.0000e-06
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4507 - mae: 4.6043 - val_loss: 9.6861 - val_mae: 8.8397 - learning_rate: 1.0000e-07
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.5733 - mae: 4.7269 - val_loss: 9.6844 - val_mae: 8.8380 - learning_rate: 1.0000e-07
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.2929 - mae: 4.4465 - val_loss: 9.6780 - val_mae: 8.8316 - learning_rate: 1.0000e-07
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Mean Squared Error: 122.04272270882929
# Root Mean Square Error: 11.047294814063273
# Root Mean Square Percentage Error: 556165702.7307899
# Mean Absolute Error: 7.40494887265982
# Mean Absolute Percentage Error: 9121752936372.006

# %% [markdown]
# # Model 1 with tanh

# %%
import os
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Dropout, Dense, GRU
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Function to calculate and display regression metrics
def regression_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    print(f"Mean Squared Error: {mse}")
    print(f"Root Mean Squared Error: {rmse}")
    print(f"Mean Absolute Error: {mae}")

# Assume `X_train`, `X_val`, `X_test`, `y_train`, `y_val`, `y_test` are preloaded

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Define a TCN block with dilations
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation("elu")(conv1)  # Apply ELU activation
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks with different dilation rates
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with ELU activation, regularization, and dropout
gru_layer = GRU(32, return_sequences=False,
                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)
gru_layer = Activation("elu")(gru_layer)  # Apply ELU activation

# Dense layers with ELU activation
dense1 = Dense(16, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Activation("elu")(dense1)  # Apply ELU activation

dense2 = Dense(8, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Activation("elu")(dense2)  # Apply ELU activation

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine the models
combined_model1 = Model(inputs=input_layer, outputs=output_layer)
combined_model1.summary()

# Compile the model with early stopping and learning rate reduction
opt = Adam(learning_rate=0.01)
combined_model1.compile(optimizer=opt, loss='mae', metrics=['mae'])
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lronplat = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5)

# Train the model
history = combined_model1.fit(X_train_norm, y_train, epochs=100, verbose=1,
                              batch_size=64,
                              validation_data=(X_val_norm, y_val),
                              callbacks=[early_stopping, lronplat])

# Evaluate the model on the test set
y_pred_combined = combined_model1.predict(X_test_norm)

# Display regression metrics
regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.title("Actual vs Predicted Values")
plt.xlabel("Samples")
plt.ylabel("Value")
plt.show()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 8, 1)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_6 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_7 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_8 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 8, 32)          │              0 │ conv1d_6[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 8, 32)          │              0 │ conv1d_7[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 8, 32)          │              0 │ conv1d_8[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 8, 32)          │              0 │ activation_12[0][0],   │
# │                           │                        │                │ activation_13[0][0],   │
# │                           │                        │                │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_2 (GRU)               │ (None, 32)             │          6,336 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 32)             │              0 │ gru_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 16)             │            528 │ activation_15[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 16)             │              0 │ dense_6[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 8)              │            136 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 8)              │              0 │ dense_7[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 1)              │              9 │ activation_17[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,393 (28.88 KB)
#  Trainable params: 7,393 (28.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 383.7946 - mae: 383.5216 - val_loss: 15.0012 - val_mae: 14.3039 - learning_rate: 0.0100
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 16.4170 - mae: 15.7104 - val_loss: 19.5747 - val_mae: 18.8513 - learning_rate: 0.0100
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 11.8926 - mae: 11.1625 - val_loss: 13.9715 - val_mae: 13.2340 - learning_rate: 0.0100
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 9.4202 - mae: 8.6804 - val_loss: 15.2055 - val_mae: 14.4567 - learning_rate: 0.0100
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 9.2200 - mae: 8.4724 - val_loss: 25.1162 - val_mae: 24.3636 - learning_rate: 0.0100
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 10.8627 - mae: 10.1074 - val_loss: 11.6369 - val_mae: 10.8826 - learning_rate: 0.0100
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 7.8399 - mae: 7.0846 - val_loss: 9.3245 - val_mae: 8.5720 - learning_rate: 0.0100
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 8.1541 - mae: 7.4032 - val_loss: 9.4764 - val_mae: 8.7215 - learning_rate: 0.0100
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 8.3774 - mae: 7.6228 - val_loss: 10.4417 - val_mae: 9.6899 - learning_rate: 0.0100
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.6349 - mae: 7.8816 - val_loss: 9.4383 - val_mae: 8.6827 - learning_rate: 0.0100
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 7.0716 - mae: 6.3171 - val_loss: 7.2204 - val_mae: 6.4706 - learning_rate: 0.0050
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 6.1944 - mae: 5.4445 - val_loss: 12.6027 - val_mae: 11.8566 - learning_rate: 0.0050
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6.3604 - mae: 5.6154 - val_loss: 9.2779 - val_mae: 8.5383 - learning_rate: 0.0050
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.6102 - mae: 5.8704 - val_loss: 11.1943 - val_mae: 10.4589 - learning_rate: 0.0050
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 5.5275 - mae: 4.7929 - val_loss: 8.7949 - val_mae: 8.0660 - learning_rate: 0.0025
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.2335 - mae: 4.5060 - val_loss: 8.6886 - val_mae: 7.9638 - learning_rate: 0.0025
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.6230 - mae: 4.8994 - val_loss: 9.8467 - val_mae: 9.1257 - learning_rate: 0.0025
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.0708 - mae: 4.3504 - val_loss: 8.6503 - val_mae: 7.9323 - learning_rate: 0.0012
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 4.7912 - mae: 4.0736 - val_loss: 8.8580 - val_mae: 8.1425 - learning_rate: 0.0012
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 4.8811 - mae: 4.1664 - val_loss: 8.4898 - val_mae: 7.7773 - learning_rate: 0.0012
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.5943 - mae: 3.8820 - val_loss: 9.3330 - val_mae: 8.6220 - learning_rate: 6.2500e-04
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 4.6016 - mae: 3.8909 - val_loss: 9.3567 - val_mae: 8.6474 - learning_rate: 6.2500e-04
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.8367 - mae: 4.1272 - val_loss: 9.7219 - val_mae: 9.0139 - learning_rate: 6.2500e-04
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 4.5216 - mae: 3.8136 - val_loss: 8.5000 - val_mae: 7.7928 - learning_rate: 3.1250e-04
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.5047 - mae: 3.7976 - val_loss: 8.9253 - val_mae: 8.2189 - learning_rate: 3.1250e-04
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.6017 - mae: 3.8955 - val_loss: 8.9556 - val_mae: 8.2502 - learning_rate: 3.1250e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Mean Squared Error: 2097.004474065108
# Root Mean Squared Error: 45.79306141835363
# Mean Absolute Error: 8.637200773869017

# %% [markdown]
# # Model 2 with relu

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization, Input, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Custom activation function for more flexibility
def custom_activation(x):
    return tf.where(x >= 0, x, tf.tanh(x) + tf.atan(x))

# Regression metrics
def regression_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"Root Mean Squared Error: {rmse:.4f}")
    print(f"Mean Absolute Error: {mae:.4f}")
    return mse, rmse, mae

# Placeholder for loading data
# Replace with actual data loading logic
# X_train, y_train, X_val, y_val, X_test, y_test = ...

# Data normalization
scaler = StandardScaler()
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# Stacked GRU layers
gru1 = GRU(64, activation='tanh', return_sequences=True, kernel_regularizer=l2(l2_strength))(input_layer)
gru1 = BatchNormalization()(gru1)
gru1 = Dropout(0.3)(gru1)

gru2 = GRU(64, activation='tanh', return_sequences=True, kernel_regularizer=l2(l2_strength))(gru1)
gru2 = BatchNormalization()(gru2)
gru2 = Dropout(0.3)(gru2)

gru3 = GRU(64, activation='tanh', return_sequences=False, kernel_regularizer=l2(l2_strength))(gru2)
gru3 = BatchNormalization()(gru3)
gru3 = Lambda(custom_activation)(gru3)

# Fully connected layers
dense1 = Dense(32, activation=None, kernel_regularizer=l2(l2_strength))(gru3)
dense1 = BatchNormalization()(dense1)
dense1 = Lambda(custom_activation)(dense1)
dense1 = Dropout(0.3)(dense1)

dense2 = Dense(16, activation=None, kernel_regularizer=l2(l2_strength))(dense1)
dense2 = BatchNormalization()(dense2)
dense2 = Lambda(custom_activation)(dense2)

# Output layer
output_layer = Dense(1, activation='linear')(dense2)

# Compile the model
model = Model(inputs=input_layer, outputs=output_layer)
opt = Adam(learning_rate=5e-4)
model.compile(optimizer=opt, loss='mae', metrics=['mae'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)

# Train the model
history = model.fit(
    X_train_norm, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_val_norm, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# Evaluate on test set
y_pred = model.predict(X_test_norm).flatten()
mse, rmse, mae = regression_metrics(y_test, y_pred)

# Plot Actual vs Predicted
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual', alpha=0.8)
plt.plot(y_pred, label='Predicted', alpha=0.8)
plt.legend()
plt.title('Actual vs Predicted')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()
# Out:
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 557.3417 - mae: 557.0970 - val_loss: 617.0924 - val_mae: 616.8818 - learning_rate: 5.0000e-04
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 548.3625 - mae: 548.1612 - val_loss: 612.2270 - val_mae: 612.0491 - learning_rate: 5.0000e-04
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 547.0326 - mae: 546.8602 - val_loss: 608.1193 - val_mae: 607.9612 - learning_rate: 5.0000e-04
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 546.5811 - mae: 546.4249 - val_loss: 607.3898 - val_mae: 607.2430 - learning_rate: 5.0000e-04
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 547.3041 - mae: 547.1594 - val_loss: 605.7408 - val_mae: 605.6013 - learning_rate: 5.0000e-04
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 539.5264 - mae: 539.3881 - val_loss: 597.8832 - val_mae: 597.7493 - learning_rate: 5.0000e-04
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 536.1775 - mae: 536.0439 - val_loss: 590.9906 - val_mae: 590.8608 - learning_rate: 5.0000e-04
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 529.7817 - mae: 529.6526 - val_loss: 586.2996 - val_mae: 586.1718 - learning_rate: 5.0000e-04
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 518.9847 - mae: 518.8570 - val_loss: 582.8892 - val_mae: 582.7628 - learning_rate: 5.0000e-04
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 518.9119 - mae: 518.7861 - val_loss: 565.5225 - val_mae: 565.3975 - learning_rate: 5.0000e-04
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 510.6371 - mae: 510.5125 - val_loss: 569.6877 - val_mae: 569.5646 - learning_rate: 5.0000e-04
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 503.7177 - mae: 503.5951 - val_loss: 555.0322 - val_mae: 554.9106 - learning_rate: 5.0000e-04
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 496.3587 - mae: 496.2374 - val_loss: 553.8637 - val_mae: 553.7433 - learning_rate: 5.0000e-04
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 490.2560 - mae: 490.1353 - val_loss: 546.7138 - val_mae: 546.5933 - learning_rate: 5.0000e-04
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 477.6633 - mae: 477.5431 - val_loss: 541.7531 - val_mae: 541.6329 - learning_rate: 5.0000e-04
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 472.1364 - mae: 472.0169 - val_loss: 529.4029 - val_mae: 529.2842 - learning_rate: 5.0000e-04
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 469.2555 - mae: 469.1364 - val_loss: 514.5919 - val_mae: 514.4717 - learning_rate: 5.0000e-04
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 449.5316 - mae: 449.4117 - val_loss: 510.8949 - val_mae: 510.7757 - learning_rate: 5.0000e-04
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 448.5096 - mae: 448.3909 - val_loss: 500.4864 - val_mae: 500.3683 - learning_rate: 5.0000e-04
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 443.9649 - mae: 443.8472 - val_loss: 493.6768 - val_mae: 493.5583 - learning_rate: 5.0000e-04
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 432.8316 - mae: 432.7137 - val_loss: 490.7208 - val_mae: 490.6029 - learning_rate: 5.0000e-04
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 420.4579 - mae: 420.3401 - val_loss: 479.8832 - val_mae: 479.7652 - learning_rate: 5.0000e-04
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 410.0614 - mae: 409.9436 - val_loss: 463.9631 - val_mae: 463.8456 - learning_rate: 5.0000e-04
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 397.4775 - mae: 397.3601 - val_loss: 453.9198 - val_mae: 453.8030 - learning_rate: 5.0000e-04
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 393.0919 - mae: 392.9751 - val_loss: 453.7331 - val_mae: 453.6142 - learning_rate: 5.0000e-04
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 378.9904 - mae: 378.8719 - val_loss: 435.5870 - val_mae: 435.4693 - learning_rate: 5.0000e-04
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 372.3206 - mae: 372.2027 - val_loss: 419.9302 - val_mae: 419.8108 - learning_rate: 5.0000e-04
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 364.6410 - mae: 364.5215 - val_loss: 403.5848 - val_mae: 403.4650 - learning_rate: 5.0000e-04
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 356.0570 - mae: 355.9370 - val_loss: 406.9313 - val_mae: 406.8113 - learning_rate: 5.0000e-04
# Epoch 30/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 339.2296 - mae: 339.1094 - val_loss: 402.7477 - val_mae: 402.6268 - learning_rate: 5.0000e-04
# Epoch 31/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 329.6189 - mae: 329.4976 - val_loss: 393.8174 - val_mae: 393.6962 - learning_rate: 5.0000e-04
# Epoch 32/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 322.9337 - mae: 322.8122 - val_loss: 374.1174 - val_mae: 373.9954 - learning_rate: 5.0000e-04
# Epoch 33/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 308.7878 - mae: 308.6655 - val_loss: 374.7986 - val_mae: 374.6751 - learning_rate: 5.0000e-04
# Epoch 34/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 296.1637 - mae: 296.0401 - val_loss: 369.6684 - val_mae: 369.5436 - learning_rate: 5.0000e-04
# Epoch 35/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 286.4937 - mae: 286.3690 - val_loss: 355.2292 - val_mae: 355.1043 - learning_rate: 5.0000e-04
# Epoch 36/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 276.4298 - mae: 276.3047 - val_loss: 330.7900 - val_mae: 330.6644 - learning_rate: 5.0000e-04
# Epoch 37/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 263.1684 - mae: 263.0430 - val_loss: 326.0270 - val_mae: 325.9008 - learning_rate: 5.0000e-04
# Epoch 38/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 255.0539 - mae: 254.9273 - val_loss: 282.8765 - val_mae: 282.7493 - learning_rate: 5.0000e-04
# Epoch 39/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 242.3833 - mae: 242.2559 - val_loss: 274.1046 - val_mae: 273.9774 - learning_rate: 5.0000e-04
# Epoch 40/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 227.7961 - mae: 227.6680 - val_loss: 285.3235 - val_mae: 285.1934 - learning_rate: 5.0000e-04
# Epoch 41/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 216.6870 - mae: 216.5564 - val_loss: 255.9039 - val_mae: 255.7711 - learning_rate: 5.0000e-04
# Epoch 42/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 208.1923 - mae: 208.0592 - val_loss: 253.9279 - val_mae: 253.7942 - learning_rate: 5.0000e-04
# Epoch 43/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 194.6759 - mae: 194.5412 - val_loss: 243.8874 - val_mae: 243.7524 - learning_rate: 5.0000e-04
# Epoch 44/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 177.2646 - mae: 177.1292 - val_loss: 223.2968 - val_mae: 223.1606 - learning_rate: 5.0000e-04
# Epoch 45/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 166.4791 - mae: 166.3426 - val_loss: 178.8905 - val_mae: 178.7528 - learning_rate: 5.0000e-04
# Epoch 46/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - loss: 156.7179 - mae: 156.5794 - val_loss: 229.8077 - val_mae: 229.6682 - learning_rate: 5.0000e-04
# Epoch 47/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 141.6749 - mae: 141.5353 - val_loss: 176.9734 - val_mae: 176.8330 - learning_rate: 5.0000e-04
# Epoch 48/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 130.5776 - mae: 130.4374 - val_loss: 166.3999 - val_mae: 166.2592 - learning_rate: 5.0000e-04
# Epoch 49/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 119.5239 - mae: 119.3829 - val_loss: 171.5382 - val_mae: 171.3961 - learning_rate: 5.0000e-04
# Epoch 50/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 109.7747 - mae: 109.6325 - val_loss: 138.4182 - val_mae: 138.2756 - learning_rate: 5.0000e-04
# Epoch 51/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 96.0212 - mae: 95.8783 - val_loss: 116.3640 - val_mae: 116.2198 - learning_rate: 5.0000e-04
# Epoch 52/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 91.4066 - mae: 91.2619 - val_loss: 96.8680 - val_mae: 96.7223 - learning_rate: 5.0000e-04
# Epoch 53/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 80.0643 - mae: 79.9181 - val_loss: 115.8225 - val_mae: 115.6746 - learning_rate: 5.0000e-04
# Epoch 54/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 70.8945 - mae: 70.7461 - val_loss: 41.3089 - val_mae: 41.1579 - learning_rate: 5.0000e-04
# Epoch 55/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 65.5970 - mae: 65.4455 - val_loss: 67.2883 - val_mae: 67.1351 - learning_rate: 5.0000e-04
# Epoch 56/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 61.8842 - mae: 61.7302 - val_loss: 49.7352 - val_mae: 49.5795 - learning_rate: 5.0000e-04
# Epoch 57/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 57.3140 - mae: 57.1577 - val_loss: 36.2917 - val_mae: 36.1341 - learning_rate: 5.0000e-04
# Epoch 58/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 54.7759 - mae: 54.6180 - val_loss: 34.0901 - val_mae: 33.9313 - learning_rate: 5.0000e-04
# Epoch 59/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 50.4525 - mae: 50.2935 - val_loss: 20.1639 - val_mae: 20.0038 - learning_rate: 5.0000e-04
# Epoch 60/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 53.3376 - mae: 53.1771 - val_loss: 46.1735 - val_mae: 46.0117 - learning_rate: 5.0000e-04
# Epoch 61/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 50.0519 - mae: 49.8900 - val_loss: 35.3228 - val_mae: 35.1600 - learning_rate: 5.0000e-04
# Epoch 62/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 53.8244 - mae: 53.6613 - val_loss: 30.8855 - val_mae: 30.7210 - learning_rate: 5.0000e-04
# Epoch 63/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 46.2299 - mae: 46.0650 - val_loss: 22.3868 - val_mae: 22.2208 - learning_rate: 5.0000e-04
# Epoch 64/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 50.0226 - mae: 49.8563 - val_loss: 15.5463 - val_mae: 15.3795 - learning_rate: 5.0000e-04
# Epoch 65/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 48.7571 - mae: 48.5899 - val_loss: 23.8155 - val_mae: 23.6470 - learning_rate: 5.0000e-04
# Epoch 66/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 48.4012 - mae: 48.2325 - val_loss: 55.8297 - val_mae: 55.6597 - learning_rate: 5.0000e-04
# Epoch 67/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 48.5014 - mae: 48.3313 - val_loss: 17.7098 - val_mae: 17.5392 - learning_rate: 5.0000e-04
# Epoch 68/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 48.4266 - mae: 48.2560 - val_loss: 26.3339 - val_mae: 26.1632 - learning_rate: 5.0000e-04
# Epoch 69/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 49.1424 - mae: 48.9711 - val_loss: 17.6982 - val_mae: 17.5264 - learning_rate: 5.0000e-04
# Epoch 70/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 49.0722 - mae: 48.9002 - val_loss: 21.5304 - val_mae: 21.3577 - learning_rate: 5.0000e-04
# Epoch 71/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 48.0803 - mae: 47.9073 - val_loss: 17.3427 - val_mae: 17.1688 - learning_rate: 5.0000e-04
# Epoch 72/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 47.7061 - mae: 47.5317 - val_loss: 21.3812 - val_mae: 21.2066 - learning_rate: 5.0000e-04
# Epoch 73/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 45.2595 - mae: 45.0844 - val_loss: 25.4600 - val_mae: 25.2840 - learning_rate: 5.0000e-04
# Epoch 74/100
# 200/202 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 46.6639 - mae: 46.4874
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 46.6497 - mae: 46.4732 - val_loss: 30.1890 - val_mae: 30.0119 - learning_rate: 5.0000e-04
# Epoch 75/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 45.0098 - mae: 44.8327 - val_loss: 9.3903 - val_mae: 9.2130 - learning_rate: 2.5000e-04
# Epoch 76/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 45.7731 - mae: 45.5958 - val_loss: 20.7951 - val_mae: 20.6178 - learning_rate: 2.5000e-04
# Epoch 77/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 45.3466 - mae: 45.1691 - val_loss: 14.5407 - val_mae: 14.3628 - learning_rate: 2.5000e-04
# Epoch 78/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 42.6470 - mae: 42.4690 - val_loss: 19.6010 - val_mae: 19.4226 - learning_rate: 2.5000e-04
# Epoch 79/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 43.6886 - mae: 43.5103 - val_loss: 23.7393 - val_mae: 23.5606 - learning_rate: 2.5000e-04
# Epoch 80/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 43.9355 - mae: 43.7568 - val_loss: 18.4091 - val_mae: 18.2299 - learning_rate: 2.5000e-04
# Epoch 81/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 44.4167 - mae: 44.2375 - val_loss: 18.4605 - val_mae: 18.2814 - learning_rate: 2.5000e-04
# Epoch 82/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 48.9307 - mae: 48.7514 - val_loss: 23.5187 - val_mae: 23.3391 - learning_rate: 2.5000e-04
# Epoch 83/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 43.5413 - mae: 43.3617 - val_loss: 15.3226 - val_mae: 15.1428 - learning_rate: 2.5000e-04
# Epoch 84/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 43.6621 - mae: 43.4823 - val_loss: 19.9566 - val_mae: 19.7765 - learning_rate: 2.5000e-04
# Epoch 85/100
# 201/202 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 43.8242 - mae: 43.6442
# Epoch 85: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 43.8215 - mae: 43.6415 - val_loss: 12.9990 - val_mae: 12.8188 - learning_rate: 2.5000e-04
# Epoch 86/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 45.0819 - mae: 44.9016 - val_loss: 14.9198 - val_mae: 14.7393 - learning_rate: 1.2500e-04
# Epoch 87/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 43.3442 - mae: 43.1637 - val_loss: 13.2264 - val_mae: 13.0459 - learning_rate: 1.2500e-04
# Epoch 88/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 40.0003 - mae: 39.8197 - val_loss: 9.9984 - val_mae: 9.8178 - learning_rate: 1.2500e-04
# Epoch 89/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 45.3563 - mae: 45.1756 - val_loss: 16.0048 - val_mae: 15.8239 - learning_rate: 1.2500e-04
# Epoch 90/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 41.0212 - mae: 40.8403 - val_loss: 15.5474 - val_mae: 15.3665 - learning_rate: 1.2500e-04
# Epoch 91/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 44.2024 - mae: 44.0216 - val_loss: 12.1428 - val_mae: 11.9617 - learning_rate: 1.2500e-04
# Epoch 92/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 40.5049 - mae: 40.3239 - val_loss: 15.0356 - val_mae: 14.8545 - learning_rate: 1.2500e-04
# Epoch 93/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 44.6831 - mae: 44.5020 - val_loss: 15.8451 - val_mae: 15.6639 - learning_rate: 1.2500e-04
# Epoch 94/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 40.4887 - mae: 40.3076 - val_loss: 16.4296 - val_mae: 16.2484 - learning_rate: 1.2500e-04
# Epoch 95/100
# 200/202 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 43.4534 - mae: 43.2722
# Epoch 95: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 43.4592 - mae: 43.2780 - val_loss: 15.3257 - val_mae: 15.1445 - learning_rate: 1.2500e-04
# Epoch 96/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 39.6037 - mae: 39.4224 - val_loss: 13.5598 - val_mae: 13.3786 - learning_rate: 6.2500e-05
# Epoch 97/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 45.0582 - mae: 44.8768 - val_loss: 17.4329 - val_mae: 17.2516 - learning_rate: 6.2500e-05
# Epoch 98/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 44.1638 - mae: 43.9825 - val_loss: 14.9927 - val_mae: 14.8114 - learning_rate: 6.2500e-05
# Epoch 99/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 40.7773 - mae: 40.5959 - val_loss: 19.0979 - val_mae: 18.9165 - learning_rate: 6.2500e-05
# Epoch 100/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 42.3731 - mae: 42.1916 - val_loss: 16.5646 - val_mae: 16.3832 - learning_rate: 6.2500e-05
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# Mean Squared Error: 480.7652
# Root Mean Squared Error: 21.9264
# Mean Absolute Error: 12.3549

# %% [markdown]
# # model 2 with own function

# %%
def custom_activation(x):
    return tf.where(x >= 0, tf.tanh(x), tf.atan(x))

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Add, GRU, Dense, Activation, Lambda
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Define your custom activation function
def custom_activation(x):
    return tf.where(x >= 0, tf.tanh(x), tf.atan(x))

# ... (Code for loading and preprocessing data) ...

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Define a TCN block with custom activation
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Lambda(custom_activation)(conv1)  # Apply custom activation function
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with custom activation
gru_layer = GRU(
    64,
    activation=None,  # No activation (we will use custom activation after the layer)
    return_sequences=False,
    kernel_regularizer=l2(l2_strength),
    recurrent_regularizer=l2(l2_strength),
    bias_regularizer=l2(l2_strength)
)(merged)
gru_layer = Lambda(custom_activation)(gru_layer)  # Apply custom activation

# Dense layers with custom activation
dense1 = Dense(32, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Lambda(custom_activation)(dense1)  # Apply custom activation

dense2 = Dense(16, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Lambda(custom_activation)(dense2)  # Apply custom activation

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine into a model
combined_model6 = Model(inputs=input_layer, outputs=output_layer)

# Compile the model with early stopping
opt = Adam(learning_rate=0.01)
combined_model6.compile(optimizer=opt, loss='mae', metrics=['mae'])

# Early stopping and learning rate scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Print the model summary
combined_model6.summary()

# Train the model
history = combined_model6.fit(
    X_train_norm, y_train,
    epochs=50,
    verbose=1,
    batch_size=64,
    validation_data=(X_val_norm, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model on the test set
y_pred_combined = combined_model6.predict(X_test_norm)

# Calculate regression metrics
mse = mean_squared_error(y_test, y_pred_combined)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred_combined)

# Print metrics
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.show()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 8, 1)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_15 (Conv1D)        │ (None, 8, 32)          │            128 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_16 (Conv1D)        │ (None, 8, 32)          │            128 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_17 (Conv1D)        │ (None, 8, 32)          │            128 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_6 (Lambda)         │ (None, 8, 32)          │              0 │ conv1d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_7 (Lambda)         │ (None, 8, 32)          │              0 │ conv1d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_8 (Lambda)         │ (None, 8, 32)          │              0 │ conv1d_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 8, 32)          │              0 │ lambda_6[0][0],        │
# │                           │                        │                │ lambda_7[0][0],        │
# │                           │                        │                │ lambda_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_5 (GRU)               │ (None, 64)             │         18,816 │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_9 (Lambda)         │ (None, 64)             │              0 │ gru_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 32)             │          2,080 │ lambda_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_10 (Lambda)        │ (None, 32)             │              0 │ dense_15[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 16)             │            528 │ lambda_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_11 (Lambda)        │ (None, 16)             │              0 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 1)              │             17 │ lambda_11[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,825 (85.25 KB)
#  Trainable params: 21,825 (85.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - loss: 540.5368 - mae: 540.3436 - val_loss: 571.2589 - val_mae: 570.9471 - learning_rate: 0.0100
# Epoch 2/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 497.0298 - mae: 496.6317 - val_loss: 536.1833 - val_mae: 535.5063 - learning_rate: 0.0100
# Epoch 3/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - loss: 463.4680 - mae: 462.6913 - val_loss: 505.6083 - val_mae: 504.5096 - learning_rate: 0.0100
# Epoch 4/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 431.9228 - mae: 430.7098 - val_loss: 478.8449 - val_mae: 477.2772 - learning_rate: 0.0100
# Epoch 5/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 403.1649 - mae: 401.4702 - val_loss: 455.2617 - val_mae: 453.0914 - learning_rate: 0.0100
# Epoch 6/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 378.8455 - mae: 376.5846 - val_loss: 434.0173 - val_mae: 431.3536 - learning_rate: 0.0100
# Epoch 7/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 362.7246 - mae: 359.9188 - val_loss: 415.5985 - val_mae: 412.3404 - learning_rate: 0.0100
# Epoch 8/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 347.6454 - mae: 344.2321 - val_loss: 399.9143 - val_mae: 396.0507 - learning_rate: 0.0100
# Epoch 9/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 333.3766 - mae: 329.3041 - val_loss: 387.3864 - val_mae: 382.1653 - learning_rate: 0.0100
# Epoch 10/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 303.3424 - mae: 297.0349 - val_loss: 334.1018 - val_mae: 325.7125 - learning_rate: 0.0100
# Epoch 11/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 262.3336 - mae: 253.7577 - val_loss: 303.4016 - val_mae: 294.1631 - learning_rate: 0.0100
# Epoch 12/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 232.0613 - mae: 222.5954 - val_loss: 264.8470 - val_mae: 254.5791 - learning_rate: 0.0100
# Epoch 13/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 201.5633 - mae: 190.9802 - val_loss: 239.8291 - val_mae: 228.2989 - learning_rate: 0.0100
# Epoch 14/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 180.0512 - mae: 168.2156 - val_loss: 218.4691 - val_mae: 205.7230 - learning_rate: 0.0100
# Epoch 15/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 161.2313 - mae: 148.1803 - val_loss: 197.5903 - val_mae: 183.5873 - learning_rate: 0.0100
# Epoch 16/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 146.2845 - mae: 131.9738 - val_loss: 178.3822 - val_mae: 163.1517 - learning_rate: 0.0100
# Epoch 17/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 131.0414 - mae: 115.5050 - val_loss: 165.7840 - val_mae: 149.3129 - learning_rate: 0.0100
# Epoch 18/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 120.5964 - mae: 103.8147 - val_loss: 147.3569 - val_mae: 129.6296 - learning_rate: 0.0100
# Epoch 19/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 106.8034 - mae: 88.7574 - val_loss: 134.2263 - val_mae: 115.2253 - learning_rate: 0.0100
# Epoch 20/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 98.7519 - mae: 79.4506 - val_loss: 125.7018 - val_mae: 105.4564 - learning_rate: 0.0100
# Epoch 21/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 92.9217 - mae: 72.3470 - val_loss: 111.1969 - val_mae: 89.6021 - learning_rate: 0.0100
# Epoch 22/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 82.7474 - mae: 60.8364 - val_loss: 101.0357 - val_mae: 78.1817 - learning_rate: 0.0100
# Epoch 23/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 78.1868 - mae: 55.0377 - val_loss: 94.7117 - val_mae: 70.7156 - learning_rate: 0.0100
# Epoch 24/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 72.5813 - mae: 48.3006 - val_loss: 83.3473 - val_mae: 58.2000 - learning_rate: 0.0100
# Epoch 25/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 66.1715 - mae: 40.7501 - val_loss: 80.8731 - val_mae: 54.6405 - learning_rate: 0.0100
# Epoch 26/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 64.2904 - mae: 37.8077 - val_loss: 75.4128 - val_mae: 48.1826 - learning_rate: 0.0100
# Epoch 27/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 59.1165 - mae: 31.6468 - val_loss: 70.3067 - val_mae: 42.1608 - learning_rate: 0.0100
# Epoch 28/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 57.8291 - mae: 29.4672 - val_loss: 68.4956 - val_mae: 39.4905 - learning_rate: 0.0100
# Epoch 29/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 55.2934 - mae: 26.0779 - val_loss: 62.4047 - val_mae: 32.5512 - learning_rate: 0.0100
# Epoch 30/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 53.9622 - mae: 23.9270 - val_loss: 59.1319 - val_mae: 28.6111 - learning_rate: 0.0100
# Epoch 31/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 52.4372 - mae: 21.7298 - val_loss: 54.3563 - val_mae: 23.1508 - learning_rate: 0.0100
# Epoch 32/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 51.7333 - mae: 20.3725 - val_loss: 55.5056 - val_mae: 23.7385 - learning_rate: 0.0100
# Epoch 33/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 62.9659 - mae: 30.9567 - val_loss: 112.4640 - val_mae: 77.6527 - learning_rate: 0.0100
# Epoch 34/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 186.0501 - mae: 150.4880 - val_loss: 246.7314 - val_mae: 208.9123 - learning_rate: 0.0100
# Epoch 35/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 218.3341 - mae: 180.3508 - val_loss: 190.0982 - val_mae: 152.0700 - learning_rate: 0.0100
# Epoch 36/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 162.4884 - mae: 124.2982 - val_loss: 328.5653 - val_mae: 290.0354 - learning_rate: 0.0100
# Epoch 37/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 225.9849 - mae: 187.4142 - val_loss: 195.0720 - val_mae: 156.5063 - learning_rate: 0.0050
# Epoch 38/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 160.9381 - mae: 122.3609 - val_loss: 120.0063 - val_mae: 81.5088 - learning_rate: 0.0050
# Epoch 39/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 125.4087 - mae: 86.9109 - val_loss: 105.2788 - val_mae: 66.7455 - learning_rate: 0.0050
# Epoch 40/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 116.0509 - mae: 77.4826 - val_loss: 149.2226 - val_mae: 110.6380 - learning_rate: 0.0050
# Epoch 41/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 129.2801 - mae: 90.6504 - val_loss: 156.1976 - val_mae: 117.2784 - learning_rate: 0.0050
# Epoch 42/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 127.5769 - mae: 88.6300 - val_loss: 123.8164 - val_mae: 84.8198 - learning_rate: 0.0025
# Epoch 43/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 119.3651 - mae: 80.3535 - val_loss: 104.0125 - val_mae: 64.8981 - learning_rate: 0.0025
# Epoch 44/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 105.9508 - mae: 66.8243 - val_loss: 101.8466 - val_mae: 62.6385 - learning_rate: 0.0025
# Epoch 45/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 125.5296 - mae: 86.2922 - val_loss: 91.0538 - val_mae: 51.7466 - learning_rate: 0.0025
# Epoch 46/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 96.0647 - mae: 56.7359 - val_loss: 131.9241 - val_mae: 92.4942 - learning_rate: 0.0025
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Mean Squared Error: 34.08639466684065
# Root Mean Squared Error: 5.838355476231355
# Mean Absolute Error: 4.640656676153289

# %% [markdown]
# # model 2 with own function 2

# %%
def custom_act(x):
    return tf.where(x>=0, x, tf.tanh(x)+tf.atan(x))

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Add, GRU, Dense, Activation, Lambda
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Define the custom activation function
def custom_activation(x):
    return tf.where(x >= 0, x, tf.tanh(x) + tf.atan(x))

# Placeholder for loading data
# Replace with your data loading logic
# Example:
# X_train, y_train = ...
# X_val, y_val = ...
# X_test, y_test = ...

# Normalize the data
scaler = StandardScaler()
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Define a TCN block with the custom activation function
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv = Conv1D(filters=nb_filters, kernel_size=kernel_size,
                  padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv = Lambda(custom_activation)(conv)  # Apply custom activation function
    return conv

# Build the TCN + GRU Model
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks with increasing dilation rates
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge outputs of TCN blocks
merged = Add()(tcn_blocks)

# GRU layer
gru_layer = GRU(
    64, activation=None, return_sequences=False,
    kernel_regularizer=l2(l2_strength),
    recurrent_regularizer=l2(l2_strength),
    bias_regularizer=l2(l2_strength)
)(merged)
gru_layer = Lambda(custom_activation)(gru_layer)

# Fully connected (Dense) layers with custom activation
dense1 = Dense(32, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Lambda(custom_activation)(dense1)

dense2 = Dense(16, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Lambda(custom_activation)(dense2)

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Compile the model
combined_model6 = Model(inputs=input_layer, outputs=output_layer)
opt = Adam(learning_rate=0.01)
combined_model6.compile(optimizer=opt, loss='mae', metrics=['mae'])

# Model summary
combined_model6.summary()

# Callbacks: Early stopping and learning rate scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Train the model
history = combined_model6.fit(
    X_train_norm, y_train,
    epochs=50,
    batch_size=64,
    validation_data=(X_val_norm, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate on test set
y_pred_combined = combined_model6.predict(X_test_norm).flatten()

# Calculate regression metrics
mse = mean_squared_error(y_test, y_pred_combined)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred_combined)

# Print metrics
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)

# Plot Actual vs Predicted
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual', alpha=0.8)
plt.plot(y_pred_combined, label='Predicted', alpha=0.8)
plt.legend()
plt.title('Actual vs Predicted')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 8, 1)           │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 8, 32)          │            128 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 8, 32)          │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 8, 32)          │              0 │ conv1d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 8, 32)          │              0 │ conv1d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 8, 32)          │              0 │ lambda[0][0],          │
# │                           │                        │                │ lambda_1[0][0],        │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru (GRU)                 │ (None, 64)             │         18,816 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 64)             │              0 │ gru[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 32)             │          2,080 │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 32)             │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 16)             │            528 │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 16)             │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │             17 │ lambda_5[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,825 (85.25 KB)
#  Trainable params: 21,825 (85.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 239.2496 - mae: 238.9565 - val_loss: 34.4254 - val_mae: 33.9384 - learning_rate: 0.0100
# Epoch 2/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 25.4054 - mae: 24.8789 - val_loss: 17.0319 - val_mae: 16.4092 - learning_rate: 0.0100
# Epoch 3/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 19.0801 - mae: 18.4261 - val_loss: 14.7933 - val_mae: 14.0712 - learning_rate: 0.0100
# Epoch 4/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 15.6912 - mae: 14.9616 - val_loss: 17.5819 - val_mae: 16.8216 - learning_rate: 0.0100
# Epoch 5/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 13.8681 - mae: 13.1028 - val_loss: 12.8344 - val_mae: 12.0502 - learning_rate: 0.0100
# Epoch 6/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 12.3512 - mae: 11.5654 - val_loss: 13.3195 - val_mae: 12.5194 - learning_rate: 0.0100
# Epoch 7/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 13.8787 - mae: 13.0753 - val_loss: 9.9873 - val_mae: 9.1801 - learning_rate: 0.0100
# Epoch 8/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 11.0763 - mae: 10.2678 - val_loss: 18.4241 - val_mae: 17.6088 - learning_rate: 0.0100
# Epoch 9/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 11.0464 - mae: 10.2280 - val_loss: 13.7345 - val_mae: 12.8892 - learning_rate: 0.0100
# Epoch 10/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 11.1669 - mae: 10.3056 - val_loss: 17.3927 - val_mae: 16.5028 - learning_rate: 0.0100
# Epoch 11/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 9.4207 - mae: 8.5284 - val_loss: 13.7396 - val_mae: 12.8521 - learning_rate: 0.0100
# Epoch 12/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 9.6886 - mae: 8.8059 - val_loss: 16.0259 - val_mae: 15.1571 - learning_rate: 0.0100
# Epoch 13/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 7.2997 - mae: 6.4352 - val_loss: 7.1738 - val_mae: 6.3241 - learning_rate: 0.0050
# Epoch 14/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 6.9719 - mae: 6.1267 - val_loss: 9.2671 - val_mae: 8.4367 - learning_rate: 0.0050
# Epoch 15/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 6.6988 - mae: 5.8727 - val_loss: 3.6383 - val_mae: 2.8256 - learning_rate: 0.0050
# Epoch 16/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.9975 - mae: 5.1897 - val_loss: 4.0167 - val_mae: 3.2215 - learning_rate: 0.0050
# Epoch 17/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 6.1965 - mae: 5.4062 - val_loss: 5.5931 - val_mae: 4.8138 - learning_rate: 0.0050
# Epoch 18/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 6.6962 - mae: 5.9117 - val_loss: 7.9885 - val_mae: 7.2097 - learning_rate: 0.0050
# Epoch 19/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 7.7958 - mae: 7.0222 - val_loss: 5.4079 - val_mae: 4.6444 - learning_rate: 0.0050
# Epoch 20/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 6.6999 - mae: 5.9406 - val_loss: 4.7693 - val_mae: 4.0200 - learning_rate: 0.0050
# Epoch 21/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 4.9636 - mae: 4.2171 - val_loss: 7.6565 - val_mae: 6.9189 - learning_rate: 0.0025
# Epoch 22/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 5.3595 - mae: 4.6247 - val_loss: 5.5758 - val_mae: 4.8498 - learning_rate: 0.0025
# Epoch 23/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 5.0507 - mae: 4.3279 - val_loss: 8.1618 - val_mae: 7.4476 - learning_rate: 0.0025
# Epoch 24/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 5.4821 - mae: 4.7703 - val_loss: 5.6566 - val_mae: 4.9544 - learning_rate: 0.0025
# Epoch 25/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 5.0691 - mae: 4.3698 - val_loss: 4.3315 - val_mae: 3.6410 - learning_rate: 0.0025
# Epoch 26/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.6760 - mae: 3.9875 - val_loss: 6.0797 - val_mae: 5.3963 - learning_rate: 0.0012
# Epoch 27/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.5310 - mae: 3.8495 - val_loss: 6.5036 - val_mae: 5.8271 - learning_rate: 0.0012
# Epoch 28/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.6219 - mae: 3.9473 - val_loss: 5.7728 - val_mae: 5.1038 - learning_rate: 0.0012
# Epoch 29/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.6099 - mae: 3.9427 - val_loss: 6.6696 - val_mae: 6.0080 - learning_rate: 0.0012
# Epoch 30/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 4.5710 - mae: 3.9110 - val_loss: 6.6918 - val_mae: 6.0375 - learning_rate: 0.0012
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Mean Squared Error: 128.87421174238793
# Root Mean Squared Error: 11.352277821758413
# Mean Absolute Error: 3.1228155356187086

# %% [markdown]
# # model 2 with elu

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Add, GRU, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Assume `X_train`, `X_val`, `X_test`, `y_train`, `y_val`, `y_test` are preloaded

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Define a TCN block with ELU activation
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation('elu')(conv1)  # Apply ELU activation
    conv1 = Dropout(0.3)(conv1)  # Dropout regularization
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=64, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)
merged = BatchNormalization()(merged)  # Batch normalization

# GRU layer with ELU activation and more units
gru_layer = GRU(
    128,  # Increased number of GRU units
    activation=None,  # No activation inside GRU (ELU applied after the layer)
    return_sequences=False,
    kernel_regularizer=l2(l2_strength),
    recurrent_regularizer=l2(l2_strength),
    bias_regularizer=l2(l2_strength)
)(merged)
gru_layer = Activation('elu')(gru_layer)  # Apply ELU activation

# Dense layers with ELU activation
dense1 = Dense(64, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = BatchNormalization()(dense1)  # Batch normalization
dense1 = Activation('elu')(dense1)  # Apply ELU activation
dense1 = Dropout(0.3)(dense1)  # Dropout regularization

dense2 = Dense(32, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = BatchNormalization()(dense2)  # Batch normalization
dense2 = Activation('elu')(dense2)  # Apply ELU activation
dense2 = Dropout(0.3)(dense2)  # Dropout regularization

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine into a model
combined_model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model with early stopping
opt = Adam(learning_rate=5e-4)  # Reduced learning rate
combined_model.compile(optimizer=opt, loss='mae', metrics=['mae'])

# Early stopping and learning rate scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)

# Print the model summary
combined_model.summary()

# Train the model
history = combined_model.fit(
    X_train_norm, y_train,
    epochs=100,
    verbose=1,
    batch_size=64,
    validation_data=(X_val_norm, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model on the test set
y_pred_combined = combined_model.predict(X_test_norm)

# Calculate regression metrics
mse = mean_squared_error(y_test, y_pred_combined)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred_combined)

# Print metrics
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.xlabel('Sample')
plt.ylabel('Value')
plt.show()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12            │ (None, 8, 1)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_39 (Conv1D)        │ (None, 8, 64)          │            256 │ input_layer_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_40 (Conv1D)        │ (None, 8, 64)          │            256 │ input_layer_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_41 (Conv1D)        │ (None, 8, 64)          │            256 │ input_layer_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_44             │ (None, 8, 64)          │              0 │ conv1d_39[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_45             │ (None, 8, 64)          │              0 │ conv1d_40[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_46             │ (None, 8, 64)          │              0 │ conv1d_41[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_53 (Dropout)      │ (None, 8, 64)          │              0 │ activation_44[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_54 (Dropout)      │ (None, 8, 64)          │              0 │ activation_45[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_55 (Dropout)      │ (None, 8, 64)          │              0 │ activation_46[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 8, 64)          │              0 │ dropout_53[0][0],      │
# │                           │                        │                │ dropout_54[0][0],      │
# │                           │                        │                │ dropout_55[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 8, 64)          │            256 │ add_14[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_14 (GRU)              │ (None, 128)            │         74,496 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_47             │ (None, 128)            │              0 │ gru_14[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_36 (Dense)          │ (None, 64)             │          8,256 │ activation_47[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 64)             │            256 │ dense_36[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_48             │ (None, 64)             │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_56 (Dropout)      │ (None, 64)             │              0 │ activation_48[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_37 (Dense)          │ (None, 32)             │          2,080 │ dropout_56[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 32)             │            128 │ dense_37[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_49             │ (None, 32)             │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_57 (Dropout)      │ (None, 32)             │              0 │ activation_49[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_38 (Dense)          │ (None, 1)              │             33 │ dropout_57[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 86,273 (337.00 KB)
#  Trainable params: 85,953 (335.75 KB)
#  Non-trainable params: 320 (1.25 KB)
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 48s 28ms/step - loss: 556.1467 - mae: 555.7885 - val_loss: 617.0839 - val_mae: 616.7490 - learning_rate: 5.0000e-04
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - loss: 553.0682 - mae: 552.7401 - val_loss: 615.0341 - val_mae: 614.7249 - learning_rate: 5.0000e-04
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 551.1526 - mae: 550.8484 - val_loss: 611.4009 - val_mae: 611.1102 - learning_rate: 5.0000e-04
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 549.3974 - mae: 549.1091 - val_loss: 604.6260 - val_mae: 604.3428 - learning_rate: 5.0000e-04
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 538.6118 - mae: 538.3282 - val_loss: 601.4781 - val_mae: 601.1930 - learning_rate: 5.0000e-04
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 537.1549 - mae: 536.8693 - val_loss: 591.3754 - val_mae: 591.0866 - learning_rate: 5.0000e-04
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 526.4521 - mae: 526.1620 - val_loss: 583.6396 - val_mae: 583.3445 - learning_rate: 5.0000e-04
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 516.5003 - mae: 516.2040 - val_loss: 574.8258 - val_mae: 574.5233 - learning_rate: 5.0000e-04
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 507.5659 - mae: 507.2604 - val_loss: 568.1739 - val_mae: 567.8591 - learning_rate: 5.0000e-04
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 495.4532 - mae: 495.1361 - val_loss: 561.0593 - val_mae: 560.7341 - learning_rate: 5.0000e-04
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 488.9693 - mae: 488.6414 - val_loss: 544.0710 - val_mae: 543.7330 - learning_rate: 5.0000e-04
# Epoch 12/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 470.1558 - mae: 469.8147 - val_loss: 521.7226 - val_mae: 521.3706 - learning_rate: 5.0000e-04
# Epoch 13/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 462.5361 - mae: 462.1779 - val_loss: 508.0849 - val_mae: 507.7106 - learning_rate: 5.0000e-04
# Epoch 14/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 448.8011 - mae: 448.4210 - val_loss: 507.2116 - val_mae: 506.8143 - learning_rate: 5.0000e-04
# Epoch 15/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 437.3483 - mae: 436.9469 - val_loss: 487.6544 - val_mae: 487.2390 - learning_rate: 5.0000e-04
# Epoch 16/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 428.2188 - mae: 427.7984 - val_loss: 471.2645 - val_mae: 470.8329 - learning_rate: 5.0000e-04
# Epoch 17/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 406.7480 - mae: 406.3116 - val_loss: 457.9646 - val_mae: 457.5151 - learning_rate: 5.0000e-04
# Epoch 18/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 399.3159 - mae: 398.8624 - val_loss: 440.3872 - val_mae: 439.9185 - learning_rate: 5.0000e-04
# Epoch 19/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 375.4199 - mae: 374.9451 - val_loss: 435.0015 - val_mae: 434.5103 - learning_rate: 5.0000e-04
# Epoch 20/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 361.9761 - mae: 361.4771 - val_loss: 406.1544 - val_mae: 405.6378 - learning_rate: 5.0000e-04
# Epoch 21/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 343.9186 - mae: 343.3964 - val_loss: 395.5418 - val_mae: 395.0013 - learning_rate: 5.0000e-04
# Epoch 22/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 329.2679 - mae: 328.7235 - val_loss: 387.2191 - val_mae: 386.6573 - learning_rate: 5.0000e-04
# Epoch 23/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 312.4703 - mae: 311.9026 - val_loss: 342.2224 - val_mae: 341.6379 - learning_rate: 5.0000e-04
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 296.8413 - mae: 296.2487 - val_loss: 319.1403 - val_mae: 318.5287 - learning_rate: 5.0000e-04
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 281.4442 - mae: 280.8257 - val_loss: 309.5109 - val_mae: 308.8747 - learning_rate: 5.0000e-04
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 260.0821 - mae: 259.4387 - val_loss: 280.1537 - val_mae: 279.4906 - learning_rate: 5.0000e-04
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 241.7368 - mae: 241.0664 - val_loss: 261.1169 - val_mae: 260.4268 - learning_rate: 5.0000e-04
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - loss: 227.2939 - mae: 226.5974 - val_loss: 233.3761 - val_mae: 232.6580 - learning_rate: 5.0000e-04
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - loss: 204.5986 - mae: 203.8733 - val_loss: 224.5599 - val_mae: 223.8130 - learning_rate: 5.0000e-04
# Epoch 30/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 187.2139 - mae: 186.4589 - val_loss: 196.5310 - val_mae: 195.7542 - learning_rate: 5.0000e-04
# Epoch 31/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 176.5173 - mae: 175.7337 - val_loss: 160.0670 - val_mae: 159.2615 - learning_rate: 5.0000e-04
# Epoch 32/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 158.1360 - mae: 157.3235 - val_loss: 157.9304 - val_mae: 157.0940 - learning_rate: 5.0000e-04
# Epoch 33/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - loss: 139.7373 - mae: 138.8943 - val_loss: 161.8111 - val_mae: 160.9473 - learning_rate: 5.0000e-04
# Epoch 34/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 132.2612 - mae: 131.3902 - val_loss: 103.8885 - val_mae: 102.9965 - learning_rate: 5.0000e-04
# Epoch 35/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - loss: 116.1457 - mae: 115.2474 - val_loss: 126.1131 - val_mae: 125.1954 - learning_rate: 5.0000e-04
# Epoch 36/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 110.8050 - mae: 109.8821 - val_loss: 101.8662 - val_mae: 100.9265 - learning_rate: 5.0000e-04
# Epoch 37/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 103.6237 - mae: 102.6779 - val_loss: 90.3642 - val_mae: 89.3996 - learning_rate: 5.0000e-04
# Epoch 38/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 98.3258 - mae: 97.3557 - val_loss: 94.7439 - val_mae: 93.7586 - learning_rate: 5.0000e-04
# Epoch 39/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 92.9917 - mae: 92.0010 - val_loss: 81.6678 - val_mae: 80.6592 - learning_rate: 5.0000e-04
# Epoch 40/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 90.6461 - mae: 89.6305 - val_loss: 51.5648 - val_mae: 50.5319 - learning_rate: 5.0000e-04
# Epoch 41/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 86.9307 - mae: 85.8932 - val_loss: 104.5562 - val_mae: 103.5084 - learning_rate: 5.0000e-04
# Epoch 42/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 91.2672 - mae: 90.2139 - val_loss: 49.5828 - val_mae: 48.5179 - learning_rate: 5.0000e-04
# Epoch 43/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 83.8991 - mae: 82.8310 - val_loss: 34.8680 - val_mae: 33.7912 - learning_rate: 5.0000e-04
# Epoch 44/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 82.9964 - mae: 81.9174 - val_loss: 47.4120 - val_mae: 46.3282 - learning_rate: 5.0000e-04
# Epoch 45/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 81.0956 - mae: 80.0096 - val_loss: 58.5563 - val_mae: 57.4674 - learning_rate: 5.0000e-04
# Epoch 46/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 82.4224 - mae: 81.3307 - val_loss: 47.5581 - val_mae: 46.4593 - learning_rate: 5.0000e-04
# Epoch 47/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 81.0278 - mae: 79.9284 - val_loss: 40.1261 - val_mae: 39.0209 - learning_rate: 5.0000e-04
# Epoch 48/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 79.9575 - mae: 78.8498 - val_loss: 45.1234 - val_mae: 44.0113 - learning_rate: 5.0000e-04
# Epoch 49/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 81.5256 - mae: 80.4098 - val_loss: 36.6602 - val_mae: 35.5415 - learning_rate: 5.0000e-04
# Epoch 50/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - loss: 79.2602 - mae: 78.1407 - val_loss: 35.7834 - val_mae: 34.6592 - learning_rate: 5.0000e-04
# Epoch 51/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 81.4190 - mae: 80.2934 - val_loss: 48.2081 - val_mae: 47.0785 - learning_rate: 5.0000e-04
# Epoch 52/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 82.2489 - mae: 81.1189 - val_loss: 43.7429 - val_mae: 42.6077 - learning_rate: 5.0000e-04
# Epoch 53/100
# 200/202 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 80.1449 - mae: 79.0079
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 80.1309 - mae: 78.9940 - val_loss: 42.2053 - val_mae: 41.0664 - learning_rate: 5.0000e-04
# Epoch 54/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 78.3536 - mae: 77.2154 - val_loss: 39.5263 - val_mae: 38.3865 - learning_rate: 2.5000e-04
# Epoch 55/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 78.3102 - mae: 77.1704 - val_loss: 52.5943 - val_mae: 51.4536 - learning_rate: 2.5000e-04
# Epoch 56/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 78.9700 - mae: 77.8292 - val_loss: 46.7804 - val_mae: 45.6376 - learning_rate: 2.5000e-04
# Epoch 57/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 80.4299 - mae: 79.2858 - val_loss: 41.3801 - val_mae: 40.2327 - learning_rate: 2.5000e-04
# Epoch 58/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 78.4087 - mae: 77.2608 - val_loss: 46.4935 - val_mae: 45.3457 - learning_rate: 2.5000e-04
# Epoch 59/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 80.2879 - mae: 79.1400 - val_loss: 62.7893 - val_mae: 61.6416 - learning_rate: 2.5000e-04
# Epoch 60/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 80.1387 - mae: 78.9904 - val_loss: 46.7910 - val_mae: 45.6387 - learning_rate: 2.5000e-04
# Epoch 61/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 79.0238 - mae: 77.8717 - val_loss: 38.3046 - val_mae: 37.1510 - learning_rate: 2.5000e-04
# Epoch 62/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 78.3979 - mae: 77.2444 - val_loss: 43.5885 - val_mae: 42.4335 - learning_rate: 2.5000e-04
# Epoch 63/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 78.1646 - mae: 77.0087
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 78.1642 - mae: 77.0083 - val_loss: 42.3111 - val_mae: 41.1540 - learning_rate: 2.5000e-04
# Epoch 64/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 79.5314 - mae: 78.3738 - val_loss: 47.4668 - val_mae: 46.3083 - learning_rate: 1.2500e-04
# Epoch 65/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 79.2067 - mae: 78.0483 - val_loss: 50.3842 - val_mae: 49.2259 - learning_rate: 1.2500e-04
# Epoch 66/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 78.2328 - mae: 77.0738 - val_loss: 46.2763 - val_mae: 45.1162 - learning_rate: 1.2500e-04
# Epoch 67/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 78.2105 - mae: 77.0501 - val_loss: 48.0427 - val_mae: 46.8830 - learning_rate: 1.2500e-04
# Epoch 68/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 78.6798 - mae: 77.5197 - val_loss: 48.9281 - val_mae: 47.7666 - learning_rate: 1.2500e-04
# Epoch 69/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 77.0798 - mae: 75.9182 - val_loss: 44.7657 - val_mae: 43.6032 - learning_rate: 1.2500e-04
# Epoch 70/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 76.8705 - mae: 75.7072 - val_loss: 49.0402 - val_mae: 47.8752 - learning_rate: 1.2500e-04
# Epoch 71/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 80.6768 - mae: 79.5115 - val_loss: 43.1121 - val_mae: 41.9464 - learning_rate: 1.2500e-04
# Epoch 72/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 78.0233 - mae: 76.8573 - val_loss: 47.2730 - val_mae: 46.1066 - learning_rate: 1.2500e-04
# Epoch 73/100
# 200/202 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 79.0826 - mae: 77.9157
# Epoch 73: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 79.0672 - mae: 77.9002 - val_loss: 48.4819 - val_mae: 47.3145 - learning_rate: 1.2500e-04
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Mean Squared Error: 1223.56884084116
# Root Mean Squared Error: 34.97954889419187
# Mean Absolute Error: 25.910652317482217

# %% [markdown]
# # model 2 with selu

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Add, GRU, Dense, Activation, Dropout
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# ... (Code for loading and preprocessing data) ...

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Define a TCN block with SELU activation
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation('selu')(conv1)  # Apply SELU activation
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with SELU activation
gru_layer = GRU(
    64,
    activation=None,  # No activation inside GRU (SELU applied after the layer)
    return_sequences=False,
    kernel_regularizer=l2(l2_strength),
    recurrent_regularizer=l2(l2_strength),
    bias_regularizer=l2(l2_strength)
)(merged)
gru_layer = Activation('selu')(gru_layer)  # Apply SELU activation

# Dense layers with SELU activation
dense1 = Dense(32, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Activation('selu')(dense1)  # Apply SELU activation

dense2 = Dense(16, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Activation('selu')(dense2)  # Apply SELU activation

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine into a model
combined_model6 = Model(inputs=input_layer, outputs=output_layer)

# Compile the model with early stopping
opt = Adam(learning_rate=0.01)
combined_model6.compile(optimizer=opt, loss='mae', metrics=['mae'])

# Early stopping and learning rate scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Print the model summary
combined_model6.summary()

# Train the model
history = combined_model6.fit(
    X_train_norm, y_train,
    epochs=50,
    verbose=1,
    batch_size=64,
    validation_data=(X_val_norm, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model on the test set
y_pred_combined = combined_model6.predict(X_test_norm)

# Calculate regression metrics
mse = mean_squared_error(y_test, y_pred_combined)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred_combined)

# Print metrics
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.show()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7             │ (None, 8, 1)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_6 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_7 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_8 (Conv1D)         │ (None, 8, 32)          │            128 │ input_layer_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_20             │ (None, 8, 32)          │              0 │ conv1d_6[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_21             │ (None, 8, 32)          │              0 │ conv1d_7[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_22             │ (None, 8, 32)          │              0 │ conv1d_8[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 8, 32)          │              0 │ activation_20[0][0],   │
# │                           │                        │                │ activation_21[0][0],   │
# │                           │                        │                │ activation_22[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_15 (GRU)              │ (None, 64)             │         18,816 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_23             │ (None, 64)             │              0 │ gru_15[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 32)             │          2,080 │ activation_23[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_24             │ (None, 32)             │              0 │ dense_21[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 16)             │            528 │ activation_24[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_25             │ (None, 16)             │              0 │ dense_22[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 1)              │             17 │ activation_25[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,825 (85.25 KB)
#  Trainable params: 21,825 (85.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - loss: 195.8567 - mae: 195.6201 - val_loss: 112.4967 - val_mae: 112.1829 - learning_rate: 0.0100
# Epoch 2/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 73.0302 - mae: 72.6749 - val_loss: 61.0555 - val_mae: 60.5657 - learning_rate: 0.0100
# Epoch 3/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 39.5972 - mae: 39.0696 - val_loss: 60.4266 - val_mae: 59.7936 - learning_rate: 0.0100
# Epoch 4/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 47.6342 - mae: 46.9549 - val_loss: 69.3897 - val_mae: 68.5992 - learning_rate: 0.0100
# Epoch 5/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 36.5756 - mae: 35.7188 - val_loss: 23.9521 - val_mae: 22.7510 - learning_rate: 0.0100
# Epoch 6/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 29.5468 - mae: 28.2113 - val_loss: 15.4731 - val_mae: 13.9509 - learning_rate: 0.0100
# Epoch 7/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 28.8463 - mae: 27.2592 - val_loss: 16.7621 - val_mae: 14.8046 - learning_rate: 0.0100
# Epoch 8/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 69.7993 - mae: 67.5617 - val_loss: 519.4634 - val_mae: 513.9685 - learning_rate: 0.0100
# Epoch 9/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 491.2455 - mae: 485.3232 - val_loss: 574.4623 - val_mae: 568.3032 - learning_rate: 0.0100
# Epoch 10/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 504.7672 - mae: 498.5721 - val_loss: 547.1739 - val_mae: 540.8511 - learning_rate: 0.0100
# Epoch 11/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 468.3162 - mae: 461.9409 - val_loss: 523.5039 - val_mae: 516.9551 - learning_rate: 0.0100
# Epoch 12/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 452.4003 - mae: 445.8188 - val_loss: 512.6934 - val_mae: 506.0124 - learning_rate: 0.0050
# Epoch 13/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 442.3569 - mae: 435.6410 - val_loss: 502.4187 - val_mae: 495.5942 - learning_rate: 0.0050
# Epoch 14/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 428.8362 - mae: 421.9743 - val_loss: 492.6039 - val_mae: 485.6250 - learning_rate: 0.0050
# Epoch 15/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 419.7321 - mae: 412.7126 - val_loss: 483.2155 - val_mae: 476.0715 - learning_rate: 0.0050
# Epoch 16/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 413.6848 - mae: 406.4976 - val_loss: 474.1569 - val_mae: 466.8376 - learning_rate: 0.0050
# Epoch 17/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 402.7864 - mae: 395.4447 - val_loss: 469.6506 - val_mae: 462.2395 - learning_rate: 0.0025
# Epoch 18/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 403.3716 - mae: 395.9367 - val_loss: 465.1347 - val_mae: 457.6284 - learning_rate: 0.0025
# Epoch 19/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 391.8520 - mae: 384.3214 - val_loss: 460.6648 - val_mae: 453.0604 - learning_rate: 0.0025
# Epoch 20/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 388.2803 - mae: 380.6501 - val_loss: 456.1973 - val_mae: 448.4906 - learning_rate: 0.0025
# Epoch 21/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 382.4147 - mae: 374.6821 - val_loss: 451.7462 - val_mae: 443.9336 - learning_rate: 0.0025
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Mean Squared Error: 598.0677674420493
# Root Mean Squared Error: 24.45542409041498
# Mean Absolute Error: 12.047576765166669

# %% [markdown]
# ## Model 2 with tanh

# %%
import os
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, Input, Add, GRU, Dense, Activation, Dropout
from tensorflow.keras import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# ... (Code for loading and preprocessing data) ...

# Create a StandardScaler object
scaler = StandardScaler()

# Normalize the training, validation, and test data
X_train_norm = scaler.fit_transform(X_train).reshape(-1, X_train.shape[1], 1)
X_val_norm = scaler.transform(X_val).reshape(-1, X_val.shape[1], 1)
X_test_norm = scaler.transform(X_test).reshape(-1, X_test.shape[1], 1)

# Define a TCN block with tanh activation
def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)
    conv1 = Activation('tanh')(conv1)  # Apply tanh activation
    return conv1

# Model definition
input_layer = Input(shape=(X_train_norm.shape[1], 1))
l2_strength = 0.001

# TCN blocks
tcn_blocks = []
for dilation_rate in [1, 2, 4]:
    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)
    tcn_blocks.append(tcn_block)

# Merge TCN blocks
merged = Add()(tcn_blocks)

# GRU layer with tanh activation
gru_layer = GRU(
    64,
    activation=None,  # No activation inside GRU (tanh applied after the layer)
    return_sequences=False,
    kernel_regularizer=l2(l2_strength),
    recurrent_regularizer=l2(l2_strength),
    bias_regularizer=l2(l2_strength)
)(merged)
gru_layer = Activation('tanh')(gru_layer)  # Apply tanh activation

# Dense layers with tanh activation
dense1 = Dense(32, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Activation('tanh')(dense1)  # Apply tanh activation

dense2 = Dense(16, activation=None, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Activation('tanh')(dense2)  # Apply tanh activation

# Output layer
output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)

# Combine into a model
combined_model6 = Model(inputs=input_layer, outputs=output_layer)

# Compile the model with early stopping
opt = Adam(learning_rate=0.01)
combined_model6.compile(optimizer=opt, loss='mae', metrics=['mae'])

# Early stopping and learning rate scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Print the model summary
combined_model6.summary()

# Train the model
history = combined_model6.fit(
    X_train_norm, y_train,
    epochs=50,
    verbose=1,
    batch_size=64,
    validation_data=(X_val_norm, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model on the test set
y_pred_combined = combined_model6.predict(X_test_norm)

# Calculate regression metrics
mse = mean_squared_error(y_test, y_pred_combined)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred_combined)

# Print metrics
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_combined, label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.show()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10            │ (None, 8, 1)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_12 (Conv1D)        │ (None, 8, 32)          │            128 │ input_layer_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_13 (Conv1D)        │ (None, 8, 32)          │            128 │ input_layer_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_14 (Conv1D)        │ (None, 8, 32)          │            128 │ input_layer_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_29             │ (None, 8, 32)          │              0 │ conv1d_12[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_30             │ (None, 8, 32)          │              0 │ conv1d_13[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_31             │ (None, 8, 32)          │              0 │ conv1d_14[0][0]        │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 8, 32)          │              0 │ activation_29[0][0],   │
# │                           │                        │                │ activation_30[0][0],   │
# │                           │                        │                │ activation_31[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_20 (GRU)              │ (None, 64)             │         18,816 │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_32             │ (None, 64)             │              0 │ gru_20[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_30 (Dense)          │ (None, 32)             │          2,080 │ activation_32[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_33             │ (None, 32)             │              0 │ dense_30[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_31 (Dense)          │ (None, 16)             │            528 │ activation_33[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_34             │ (None, 16)             │              0 │ dense_31[0][0]         │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_32 (Dense)          │ (None, 1)              │             17 │ activation_34[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,825 (85.25 KB)
#  Trainable params: 21,825 (85.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 541.2990 - mae: 541.1299 - val_loss: 582.1456 - val_mae: 581.9557 - learning_rate: 0.0100
# Epoch 2/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 511.4029 - mae: 511.1862 - val_loss: 554.4285 - val_mae: 554.0739 - learning_rate: 0.0100
# Epoch 3/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 482.9626 - mae: 482.5371 - val_loss: 529.6323 - val_mae: 528.9619 - learning_rate: 0.0100
# Epoch 4/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 454.9763 - mae: 454.2072 - val_loss: 507.1837 - val_mae: 506.0894 - learning_rate: 0.0100
# Epoch 5/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 433.2388 - mae: 432.0215 - val_loss: 486.9257 - val_mae: 485.3165 - learning_rate: 0.0100
# Epoch 6/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 414.4675 - mae: 412.7149 - val_loss: 468.6174 - val_mae: 466.4151 - learning_rate: 0.0100
# Epoch 7/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 394.0445 - mae: 391.6853 - val_loss: 451.7899 - val_mae: 448.9311 - learning_rate: 0.0100
# Epoch 8/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 372.7231 - mae: 369.6862 - val_loss: 436.2835 - val_mae: 432.6973 - learning_rate: 0.0100
# Epoch 9/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 363.4285 - mae: 359.6433 - val_loss: 422.7182 - val_mae: 417.9738 - learning_rate: 0.0100
# Epoch 10/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 348.0703 - mae: 343.2894 - val_loss: 409.9640 - val_mae: 404.7427 - learning_rate: 0.0100
# Epoch 11/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 338.8322 - mae: 333.3407 - val_loss: 400.1731 - val_mae: 393.0282 - learning_rate: 0.0100
# Epoch 12/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 330.1173 - mae: 322.9698 - val_loss: 389.9721 - val_mae: 382.5082 - learning_rate: 0.0100
# Epoch 13/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 324.0999 - mae: 316.4658 - val_loss: 381.3866 - val_mae: 373.2186 - learning_rate: 0.0100
# Epoch 14/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 316.9966 - mae: 308.6395 - val_loss: 373.9045 - val_mae: 364.9547 - learning_rate: 0.0100
# Epoch 15/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 313.5057 - mae: 304.3683 - val_loss: 367.5690 - val_mae: 357.8395 - learning_rate: 0.0100
# Epoch 16/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 307.1400 - mae: 297.2128 - val_loss: 362.1205 - val_mae: 351.6185 - learning_rate: 0.0100
# Epoch 17/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 303.2767 - mae: 292.5949 - val_loss: 357.5331 - val_mae: 346.2948 - learning_rate: 0.0100
# Epoch 18/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 303.9995 - mae: 292.5785 - val_loss: 353.6370 - val_mae: 341.6963 - learning_rate: 0.0100
# Epoch 19/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 304.7305 - mae: 292.5251 - val_loss: 351.5056 - val_mae: 338.0040 - learning_rate: 0.0100
# Epoch 20/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 297.3170 - mae: 283.7434 - val_loss: 348.6126 - val_mae: 334.7125 - learning_rate: 0.0100
# Epoch 21/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 297.8383 - mae: 283.8271 - val_loss: 346.3696 - val_mae: 332.0616 - learning_rate: 0.0100
# Epoch 22/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 297.7624 - mae: 283.3558 - val_loss: 344.4749 - val_mae: 329.7678 - learning_rate: 0.0100
# Epoch 23/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 296.0180 - mae: 281.2460 - val_loss: 342.9971 - val_mae: 327.9531 - learning_rate: 0.0100
# Epoch 24/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 294.5654 - mae: 279.4273 - val_loss: 341.7664 - val_mae: 326.4203 - learning_rate: 0.0100
# Epoch 25/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 293.7576 - mae: 278.3486 - val_loss: 340.9053 - val_mae: 325.3486 - learning_rate: 0.0100
# Epoch 26/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 297.2239 - mae: 281.6284 - val_loss: 340.2372 - val_mae: 324.5165 - learning_rate: 0.0100
# Epoch 27/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 295.3268 - mae: 279.5816 - val_loss: 339.8123 - val_mae: 324.0011 - learning_rate: 0.0100
# Epoch 28/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 294.5266 - mae: 278.6750 - val_loss: 339.3784 - val_mae: 323.4637 - learning_rate: 0.0100
# Epoch 29/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 294.4486 - mae: 278.5054 - val_loss: 339.1213 - val_mae: 323.1613 - learning_rate: 0.0100
# Epoch 30/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 296.6986 - mae: 280.7258 - val_loss: 338.9719 - val_mae: 323.0015 - learning_rate: 0.0100
# Epoch 31/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 295.6251 - mae: 279.6322 - val_loss: 338.7278 - val_mae: 322.7060 - learning_rate: 0.0100
# Epoch 32/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 293.8865 - mae: 277.8937 - val_loss: 338.6656 - val_mae: 322.6582 - learning_rate: 0.0100
# Epoch 33/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 299.0078 - mae: 282.9146 - val_loss: 339.1294 - val_mae: 322.5767 - learning_rate: 0.0100
# Epoch 34/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 295.7174 - mae: 279.2163 - val_loss: 338.9898 - val_mae: 322.5668 - learning_rate: 0.0100
# Epoch 35/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 295.7930 - mae: 279.3622 - val_loss: 338.8871 - val_mae: 322.5221 - learning_rate: 0.0100
# Epoch 36/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 295.3456 - mae: 278.9791 - val_loss: 338.8285 - val_mae: 322.5157 - learning_rate: 0.0100
# Epoch 37/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 296.0397 - mae: 279.7571 - val_loss: 338.7924 - val_mae: 322.5286 - learning_rate: 0.0100
# Epoch 38/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 294.7589 - mae: 278.4842 - val_loss: 338.7908 - val_mae: 322.5558 - learning_rate: 0.0050
# Epoch 39/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 289.3129 - mae: 273.0599 - val_loss: 239.9996 - val_mae: 222.8364 - learning_rate: 0.0050
# Epoch 40/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 182.0381 - mae: 164.2367 - val_loss: 212.9203 - val_mae: 193.4885 - learning_rate: 0.0050
# Epoch 41/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 161.8867 - mae: 142.0047 - val_loss: 201.0090 - val_mae: 179.8992 - learning_rate: 0.0050
# Epoch 42/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 153.1256 - mae: 131.6390 - val_loss: 186.6015 - val_mae: 164.0474 - learning_rate: 0.0050
# Epoch 43/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 139.8105 - mae: 116.9174 - val_loss: 195.1744 - val_mae: 171.2729 - learning_rate: 0.0050
# Epoch 44/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 141.6964 - mae: 117.4127 - val_loss: 169.0379 - val_mae: 143.7743 - learning_rate: 0.0050
# Epoch 45/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 127.4037 - mae: 101.8472 - val_loss: 163.1275 - val_mae: 136.7124 - learning_rate: 0.0050
# Epoch 46/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 125.3981 - mae: 98.6948 - val_loss: 157.2386 - val_mae: 129.7065 - learning_rate: 0.0050
# Epoch 47/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 117.6091 - mae: 89.8072 - val_loss: 151.0593 - val_mae: 122.4358 - learning_rate: 0.0050
# Epoch 48/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 134.9845 - mae: 105.8541 - val_loss: 151.4782 - val_mae: 121.4272 - learning_rate: 0.0050
# Epoch 49/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 115.0349 - mae: 84.7163 - val_loss: 144.3937 - val_mae: 113.2459 - learning_rate: 0.0050
# Epoch 50/50
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 109.4067 - mae: 77.9952 - val_loss: 137.6258 - val_mae: 105.3987 - learning_rate: 0.0050
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Mean Squared Error: 364.397315269566
# Root Mean Squared Error: 19.089193677826362
# Mean Absolute Error: 11.318339067049305

# %% [markdown]
# # Model 6

# %%
import os

from sklearn.preprocessing import StandardScaler

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Concatenate, Dropout, Dense, GRU

from tensorflow.keras import Model

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

import matplotlib.pyplot as plt



# ... (Code for loading data and other preprocessing steps) ...



# Create a StandardScaler object

scaler = StandardScaler()



# Normalize the training data

X_train_norm = scaler.fit_transform(X_train)

# Normalize the validation data using the same scaler object

X_val_norm = scaler.transform(X_val)

# Normalize the testing data using the same scaler object

X_test_norm = scaler.transform(X_test)



# Define a TCN block with dilations

def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):

    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)

    conv1 = Activation('relu')(conv1)

    return conv1



# Model definition

input_layer = Input(shape=(X_train_norm.shape[1], 1))

l2_strength = 0.001



# TCN block

tcn_blocks = []

for dilation_rate in [1, 2, 4]:

    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)

    tcn_blocks.append(tcn_block)



# Merge TCN blocks

merged = Add()(tcn_blocks)



# GRU layer with regularization and dropout

gru_layer = GRU(64, activation='relu', return_sequences=False,

                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)



# Dense layers

dense1 = Dense(32, activation='relu', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)

dense2 = Dense(16, activation='relu', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)



# Output layer

output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)



# Combine the models

combined_model6 = Model(inputs=input_layer, outputs=output_layer)



# Compile the model with early stopping

opt = Adam(learning_rate=0.01)

combined_model6.compile(optimizer=opt, loss='mae', metrics=['mae'])

early_stopping = EarlyStopping(monitor='val_loss', patience=15)

combined_model6.summary()

# Train the model

history = combined_model6.fit(X_train_norm, y_train, epochs=50, verbose=1,

                             batch_size=64,

                             validation_data=(X_val_norm, y_val),

                             callbacks=[early_stopping, lronplat])



# Evaluate the model on the test set

y_pred_combined = combined_model6.predict(X_test_norm)



regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values

plt.plot(y_test, label='Actual')

plt.plot(y_pred_combined, label='Predicted')

plt.legend()

plt.show()

# %% [markdown]
# # Model 6 with Trh

# %%
import os

from sklearn.preprocessing import StandardScaler

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.layers import Conv1D, Input, Activation, Add, Concatenate, Dropout, Dense, GRU

from tensorflow.keras import Model

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.regularizers import l2

import matplotlib.pyplot as plt



# ... (Code for loading data and other preprocessing steps) ...



# Create a StandardScaler object

scaler = StandardScaler()



# Normalize the training data

X_train_norm = scaler.fit_transform(X_train)

# Normalize the validation data using the same scaler object

X_val_norm = scaler.transform(X_val)

# Normalize the testing data using the same scaler object

X_test_norm = scaler.transform(X_test)



# Define a TCN block with dilations

def dilated_tcn_block(input_layer, nb_filters, kernel_size, dilation_rate):

    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, padding='causal', dilation_rate=dilation_rate)(input_layer)

    conv1 = Trh()(conv1)

    return conv1



# Model definition

input_layer = Input(shape=(X_train_norm.shape[1], 1))

l2_strength = 0.001



# TCN block

tcn_blocks = []

for dilation_rate in [1, 2, 4]:

    tcn_block = dilated_tcn_block(input_layer, nb_filters=32, kernel_size=3, dilation_rate=dilation_rate)

    tcn_blocks.append(tcn_block)



# Merge TCN blocks

merged = Add()(tcn_blocks)



# GRU layer with regularization and dropout

gru_layer = GRU(64, return_sequences=False,

                kernel_regularizer=l2(l2_strength), recurrent_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(merged)

gru_layer = Trh()(gru_layer)

# Dense layers

dense1 = Dense(32, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(gru_layer)
dense1 = Trh()(dense1)

dense2 = Dense(16, kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense1)
dense2 = Trh()(dense2)



# Output layer

output_layer = Dense(1, activation='linear', kernel_regularizer=l2(l2_strength), bias_regularizer=l2(l2_strength))(dense2)



# Combine the models

combined_model6 = Model(inputs=input_layer, outputs=output_layer)



# Compile the model with early stopping

opt = Adam(learning_rate=0.01)

combined_model6.compile(optimizer=opt, loss='mae', metrics=['mae'])

early_stopping = EarlyStopping(monitor='val_loss', patience=15)

combined_model6.summary()

# Train the model

history = combined_model6.fit(X_train_norm, y_train, epochs=50, verbose=1,

                             batch_size=64,

                             validation_data=(X_val_norm, y_val),

                             callbacks=[early_stopping, lronplat])



# Evaluate the model on the test set

y_pred_combined = combined_model6.predict(X_test_norm)



regression_metrics(y_test, y_pred_combined)

# Plot the comparison between the predicted and actual values

plt.plot(y_test, label='Actual')

plt.plot(y_pred_combined, label='Predicted')

plt.legend()

plt.show()

# %% [markdown]
# # Observation:

# %% [markdown]
# * The average of losses of all the models for different functions is less for "Tar" function.
# * The minimum of losses is for "Trh" function.

# %%
y_pred_combined = combined_model3.predict([X_test_norm])
regression_metrics(y_test, y_pred_combined)
plot_comparison(y_test=y_test, y_pred=y_pred_combined, xlabel="Cycle Index", ylabel="RUL", dark_mode=False)
